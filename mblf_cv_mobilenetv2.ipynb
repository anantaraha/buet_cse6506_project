# %% [markdown]
# # Mulberry Leaf: Cross-Validation on MobileNetV2
# ### ***Dataset: Mulberry Leaf Dataset https://www.kaggle.com/datasets/nahiduzzaman13/mulberry-leaf-dataset [No Preprocessing]***

# %%
import pandas as pd
import numpy as np
import shutil
import zipfile
from functools import reduce
from datetime import datetime
from os import path, makedirs, remove, environ, listdir
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, f1_score, roc_curve, auc

import tensorflow as tf

# Set environment variable to suppress TensorFlow's lower-level logs
environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
tf.get_logger().setLevel('ERROR')

from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Dropout, Multiply, Activation, GlobalAveragePooling2D, Multiply, Reshape
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.metrics import Precision, Recall


from tensorflow.keras import mixed_precision
# Enable mixed precision
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)

plt.rcParams['font.family'] = 'serif'            # Use a specific font
plt.rcParams['font.size'] = 14                   # Set a general font size

# %%
def imshow(imgs, titles=None):
    '''Utility class for showing images.'''
    r, c = 3, 4
    plt.figure(figsize=(16, 12))
    for idx in range(1, min(r*c, len(imgs))+1):
        plt.subplot(r, c, idx)
        plt.axis('off')
        if titles != None and idx-1 < len(titles):
            plt.title(titles[idx-1])
        plt.imshow(imgs[idx-1], cmap='plasma')    
    plt.show()

def se_block(x, ratio=8):
    """Contains the implementation of Squeeze-and-Excitation(SE) block.
    As described in https://arxiv.org/abs/1709.01507.
    """
    num_channels = K.int_shape(x)[-1]

    se = GlobalAveragePooling2D(name='block_se_GAP')(x)
    se = Reshape((1, 1, num_channels), name='block_se_reshape')(se)
    se = Dense(num_channels // ratio, 
                      name='block_se_dense_1', 
                      activation='relu',
                      kernel_initializer='he_normal',
                      use_bias=True,
                      bias_initializer='zeros')(se)
    se = Dense(num_channels,
                      name='block_se_dense_2', 
                      activation='sigmoid',
                      kernel_initializer='he_normal',
                      use_bias=True,
                      bias_initializer='zeros')(se)

    return Multiply(name='block_se_multiply')([x, se])

def process_image(image, label):
    image = tf.cast(image/255. ,tf.float32)
    return image,label

def get_predictions(model, ds):
    y_true, y_pred = [], []
    for images, labels in ds:
        preds = model.predict(images, verbose=0)
        y_true.extend(labels.numpy())
        y_pred.extend(preds)

    true_labels = np.argmax(y_true, axis=1)
    pred_labels = np.argmax(y_pred, axis=1)
    
    return y_true, y_pred, true_labels, pred_labels

def plot_roc_auc(y_true, y_pred, num_classes, display_labels, title=None):
    class_auc_lst = []
    plt.figure(figsize=(10, 6))
    for i in range(num_classes):
        # One-vs-rest for class `i`
        y_true_class = [y[i] for y in y_true]
        y_pred_class = [y[i] for y in y_pred]
        
        fpr, tpr, _ = roc_curve(y_true_class, y_pred_class)
        class_auc = auc(fpr, tpr)
        class_auc_lst.append(class_auc)
        
        # Plot ROC curve for each class
        plt.plot(fpr, tpr, label=f'{display_labels[i]} (AUC = {class_auc:.4f})')
    
    # Finalize and display plot
    plt.plot([0, 1], [0, 1], color='r', linestyle='--', lw=2)
    plt.title('ROC Curve' if not title else title)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend(loc="lower right")
    plt.show()
    
    return class_auc_lst

# %% [markdown]
# # 1. Fetch Dataset

# %%
ROOT_INPUT_DIR = '/kaggle/input/mblf-dataprep/'
ROOT_OUTPUT_DIR = '/kaggle/working/'

NEW_DATA_DIR = path.join(ROOT_OUTPUT_DIR, 'data')
TRAIN_DIR = path.join(ROOT_OUTPUT_DIR, 'data/train')
TEST_DIR = path.join(ROOT_OUTPUT_DIR, 'data/test')

IMG_SIZE = 224
BATCH_SIZE = 64
INPUT_SHAPE = (IMG_SIZE, IMG_SIZE, 3)
EPOCHS = 80
LEARNING_RATE = 2e-5

TIMESTAMP = datetime.now().strftime('%Y%m%d_%H%M%S')
N_FOLDS = 5
DISPLAY_LABELS = ['Disease Free', 'Leaf Rust', 'Leaf Spot']

# %%
## Fresh data from storage
#
# Clean up older files
_path_to_temp_model = path.join(ROOT_OUTPUT_DIR, 'model_temp.keras')
if path.exists(_path_to_temp_model):
    remove(_path_to_temp_model)
    print('Deleted:', _path_to_temp_model)

if path.exists(NEW_DATA_DIR):
    shutil.rmtree(NEW_DATA_DIR, ignore_errors=True)
    print('Deleted:', NEW_DATA_DIR)

# %% [markdown]
# # 2. Construct Model

# %%
def build_model_mobilenetv2(lr=LEARNING_RATE):
    # Load base model without the top layer
    base_model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE)
    # Add custom layers
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)
    x = Dense(128)(x)
    x = Dense(3)(x)  # 3 classes
    op = Activation('softmax', dtype='float32')(x)

    # Create the new model
    model = Model(name='MobileNetV2', inputs=base_model.input, outputs=op)
    
    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), 
        loss='categorical_crossentropy', 
        metrics=[
            'accuracy', 
            Precision(name='precision'), 
            Recall(name='recall')
        ]
    )

    return model

# %%
## Show summary

build_model_mobilenetv2().summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "MobileNetV2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 112, 112,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 112, 112,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 112, 112,  │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 112, 112,  │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 112, 112,  │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 112, 112,  │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 113, 113,  │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 56, 56,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 56, 56,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 56, 56,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 56, 56,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 56, 56,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 56, 56,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 56, 56,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 56, 56,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 56, 56,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 56, 56,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 56, 56,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 56, 56,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 56, 56,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 56, 56,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 56, 56,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 56, 56,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 56, 56,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 57, 57,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 28, 28,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 28, 28,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 28, 28,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 28, 28,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 28, 28,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 28, 28,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 28, 28,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 28, 28,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 28, 28,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 28, 28,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 28, 28,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 28, 28,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 28, 28,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 28, 28,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 28, 28,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 28, 28,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 28, 28,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 28, 28,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 28, 28,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 28, 28,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 28, 28,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 28, 28,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 28, 28,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 28, 28,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 28, 28,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 28, 28,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 29, 29,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 14, 14,    │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 14, 14,    │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 14, 14,    │          0 │ block_6_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 14, 14,    │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 14, 14,    │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 14, 14,    │     24,576 │ block_6_project_… │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 14, 14,    │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 14, 14,    │          0 │ block_7_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 14, 14,    │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 14, 14,    │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 14, 14,    │          0 │ block_7_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 14, 14,    │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 14, 14,    │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 14, 14,    │          0 │ block_6_project_… │
# │                     │ 64)               │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 14, 14,    │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 14, 14,    │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 14, 14,    │          0 │ block_8_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 14, 14,    │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 14, 14,    │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 14, 14,    │          0 │ block_8_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 14, 14,    │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 14, 14,    │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 14, 14,    │          0 │ block_7_add[0][0… │
# │                     │ 64)               │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 14, 14,    │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 14, 14,    │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 14, 14,    │          0 │ block_9_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 14, 14,    │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 14, 14,    │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 14, 14,    │          0 │ block_9_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 14, 14,    │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 14, 14,    │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 14, 14,    │          0 │ block_8_add[0][0… │
# │                     │ 64)               │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 14, 14,    │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 14, 14,    │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 14, 14,    │          0 │ block_10_expand_… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 14, 14,    │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 14, 14,    │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 14, 14,    │          0 │ block_10_depthwi… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 14, 14,    │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 14, 14,    │        384 │ block_10_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 14, 14,    │     55,296 │ block_10_project… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 14, 14,    │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 14, 14,    │          0 │ block_11_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 14, 14,    │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 14, 14,    │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 14, 14,    │          0 │ block_11_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 14, 14,    │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 14, 14,    │        384 │ block_11_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 14, 14,    │          0 │ block_10_project… │
# │                     │ 96)               │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 14, 14,    │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 14, 14,    │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 14, 14,    │          0 │ block_12_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 14, 14,    │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 14, 14,    │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 14, 14,    │          0 │ block_12_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 14, 14,    │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 14, 14,    │        384 │ block_12_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 14, 14,    │          0 │ block_11_add[0][… │
# │                     │ 96)               │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 14, 14,    │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 14, 14,    │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 14, 14,    │          0 │ block_13_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 15, 15,    │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 7, 7, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 7, 7, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 7, 7, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 7, 7, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 7, 7, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 7, 7, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 7, 7, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 7, 7, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 7, 7, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 7, 7, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 7, 7, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 7, 7, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 7, 7, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 7, 7, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 7, 7, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 7, 7, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 7, 7, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 7, 7, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 7, 7, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 7, 7, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 7, 7, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 7, 7, 320) │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 7, 7,      │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 7, 7,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 7, 7,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    163,968 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 3)         │        387 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 3)         │          0 │ dense_1[0][0]     │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,422,339 (9.24 MB)
#  Trainable params: 2,388,227 (9.11 MB)
#  Non-trainable params: 34,112 (133.25 KB)

# %% [markdown]
# # 3. Train & Evaluate

# %%
score_lst = []
df_lst = []
cm_lst = []
f1_lst = []
all_y_true = []
all_y_pred = []

for i in range(N_FOLDS):
    print('================================================================================')
    print(f'Fold #{i+1}')
    print('================================================================================')
    _fold_str = f'fold{i+1}'
    
    # Unzipping
    _path_to_zip_file = path.join(
        ROOT_INPUT_DIR, 'data', _fold_str+'.zip'
    )
    makedirs(NEW_DATA_DIR, exist_ok=True)
    with zipfile.ZipFile(_path_to_zip_file, 'r') as zip_ref:
        zip_ref.extractall(NEW_DATA_DIR)
        print(f'Extracted {_fold_str} from {_path_to_zip_file}')
    
    # Prepare tensorflow datasets
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        TRAIN_DIR,
        color_mode='rgb',
        seed=1234, 
        label_mode="categorical", 
        image_size=(IMG_SIZE, IMG_SIZE), 
        batch_size=BATCH_SIZE
    )
    test_ds = tf.keras.preprocessing.image_dataset_from_directory(
        TEST_DIR,
        color_mode='rgb',
        seed=1234, 
        label_mode="categorical", 
        image_size=(IMG_SIZE, IMG_SIZE), 
        batch_size=BATCH_SIZE
    )
    train_ds = train_ds.map(process_image)
    test_ds = test_ds.map(process_image)

    # Compile model
    model = build_model_mobilenetv2()
    
    # Training
    cb = [
        ModelCheckpoint(filepath=path.join(ROOT_OUTPUT_DIR, 'model_temp.keras'), monitor='val_accuracy', mode='max', save_best_only=True)
    ]
    history = model.fit(train_ds, callbacks=cb, validation_data=test_ds, epochs=EPOCHS, verbose=2)
    
    # Saving
    MODEL_SAVE_PATH = path.join(ROOT_OUTPUT_DIR, f'model_mblf_mobilenetv2_{TIMESTAMP}_{_fold_str}.keras')
    HISTORY_SAVE_PATH = path.join(ROOT_OUTPUT_DIR, f'history_mblf_mobilenetv2_{TIMESTAMP}_{_fold_str}.csv')
    shutil.move(path.join(ROOT_OUTPUT_DIR, 'model_temp.keras'), MODEL_SAVE_PATH)
    print('\nModel saved in:', MODEL_SAVE_PATH)
    
    # Save the history to a CSV file
    df = pd.DataFrame(history.history)
    df_lst.append(df)
    df.to_csv(HISTORY_SAVE_PATH)
    print('History saved in:', HISTORY_SAVE_PATH)
    print('')

    # Load again and evaluate
    saved_model = load_model(MODEL_SAVE_PATH)
    score = saved_model.evaluate(test_ds, verbose=0)
    score_lst.append(score)

    # Confusion matrix + F1 Score + AUC-ROC
    y_true, y_pred, true_labels, pred_labels = get_predictions(model=saved_model, ds=test_ds)
    
    cf_matrix = confusion_matrix(true_labels, pred_labels)
    cm_lst.append(cf_matrix)
    f1 = f1_score(true_labels, pred_labels, average='micro')
    f1_lst.append(f1)
    all_y_true.append(y_true)
    all_y_pred.append(y_pred)
    
    print(classification_report(true_labels, pred_labels, target_names=DISPLAY_LABELS))
    print('')
    
    # Cleaning
    shutil.rmtree(NEW_DATA_DIR)
    pass
# Out:
# ================================================================================
# Fold #1
# ================================================================================
# Extracted fold1 from /kaggle/input/mblf-dataprep/data/fold1.zip
# Found 7517 files belonging to 3 classes.
# Found 219 files belonging to 3 classes.
# Epoch 1/80
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733774983.422192      64 service.cc:145] XLA service 0x789ea00024e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733774983.422258      64 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1733775020.396303      64 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 118/118 - 113s - 955ms/step - accuracy: 0.8044 - loss: 0.4831 - precision: 0.8248 - recall: 0.7805 - val_accuracy: 0.7078 - val_loss: 0.7460 - val_precision: 0.7103 - val_recall: 0.6941
# Epoch 2/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9693 - loss: 0.0958 - precision: 0.9714 - recall: 0.9673 - val_accuracy: 0.7671 - val_loss: 0.6359 - val_precision: 0.7696 - val_recall: 0.7626
# Epoch 3/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9848 - loss: 0.0464 - precision: 0.9861 - recall: 0.9839 - val_accuracy: 0.8128 - val_loss: 0.4780 - val_precision: 0.8119 - val_recall: 0.8082
# Epoch 4/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9940 - loss: 0.0243 - precision: 0.9943 - recall: 0.9933 - val_accuracy: 0.8493 - val_loss: 0.3746 - val_precision: 0.8493 - val_recall: 0.8493
# Epoch 5/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9967 - loss: 0.0144 - precision: 0.9971 - recall: 0.9965 - val_accuracy: 0.8813 - val_loss: 0.3400 - val_precision: 0.8853 - val_recall: 0.8813
# Epoch 6/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9976 - loss: 0.0107 - precision: 0.9976 - recall: 0.9973 - val_accuracy: 0.9224 - val_loss: 0.2993 - val_precision: 0.9224 - val_recall: 0.9224
# Epoch 7/80
# 118/118 - 12s - 99ms/step - accuracy: 0.9985 - loss: 0.0079 - precision: 0.9985 - recall: 0.9985 - val_accuracy: 0.9361 - val_loss: 0.2795 - val_precision: 0.9361 - val_recall: 0.9361
# Epoch 8/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9993 - loss: 0.0052 - precision: 0.9993 - recall: 0.9993 - val_accuracy: 0.9361 - val_loss: 0.2496 - val_precision: 0.9361 - val_recall: 0.9361
# Epoch 9/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9992 - loss: 0.0052 - precision: 0.9992 - recall: 0.9991 - val_accuracy: 0.9361 - val_loss: 0.2434 - val_precision: 0.9404 - val_recall: 0.9361
# Epoch 10/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 0.0030 - precision: 0.9999 - recall: 0.9997 - val_accuracy: 0.9361 - val_loss: 0.2315 - val_precision: 0.9404 - val_recall: 0.9361
# Epoch 11/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9997 - loss: 0.0030 - precision: 0.9997 - recall: 0.9996 - val_accuracy: 0.9361 - val_loss: 0.2277 - val_precision: 0.9404 - val_recall: 0.9361
# Epoch 12/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9992 - loss: 0.0031 - precision: 0.9992 - recall: 0.9992 - val_accuracy: 0.9452 - val_loss: 0.2087 - val_precision: 0.9495 - val_recall: 0.9452
# Epoch 13/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9993 - loss: 0.0024 - precision: 0.9993 - recall: 0.9993 - val_accuracy: 0.9498 - val_loss: 0.1970 - val_precision: 0.9495 - val_recall: 0.9452
# Epoch 14/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9999 - loss: 0.0016 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9543 - val_loss: 0.2023 - val_precision: 0.9541 - val_recall: 0.9498
# Epoch 15/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9999 - loss: 0.0019 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9635 - val_loss: 0.1853 - val_precision: 0.9679 - val_recall: 0.9635
# Epoch 16/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9993 - loss: 0.0017 - precision: 0.9993 - recall: 0.9993 - val_accuracy: 0.9589 - val_loss: 0.1880 - val_precision: 0.9633 - val_recall: 0.9589
# Epoch 17/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9997 - loss: 0.0012 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9589 - val_loss: 0.1871 - val_precision: 0.9631 - val_recall: 0.9543
# Epoch 18/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 0.0011 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9543 - val_loss: 0.1822 - val_precision: 0.9543 - val_recall: 0.9543
# Epoch 19/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 6.3878e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9589 - val_loss: 0.1795 - val_precision: 0.9589 - val_recall: 0.9589
# Epoch 20/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 6.0139e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9589 - val_loss: 0.1776 - val_precision: 0.9589 - val_recall: 0.9589
# Epoch 21/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 5.2797e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.1831 - val_precision: 0.9677 - val_recall: 0.9589
# Epoch 22/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 3.9979e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.1812 - val_precision: 0.9679 - val_recall: 0.9635
# Epoch 23/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 4.7960e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.1855 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 24/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9999 - loss: 5.4022e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9680 - val_loss: 0.1841 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 25/80
# 118/118 - 12s - 100ms/step - accuracy: 1.0000 - loss: 3.0408e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.1857 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 26/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 7.8319e-04 - precision: 1.0000 - recall: 0.9999 - val_accuracy: 0.9635 - val_loss: 0.1936 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 27/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 5.9441e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9680 - val_loss: 0.1880 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 28/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9997 - loss: 8.7344e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9726 - val_loss: 0.1711 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 29/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.3154e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.1712 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 30/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 2.4937e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.1717 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 31/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 5.0538e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9726 - val_loss: 0.1752 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 32/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 1.8792e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.1718 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 33/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.1711e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.1691 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 34/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 6.3508e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9680 - val_loss: 0.1620 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 35/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 3.2457e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9635 - val_loss: 0.1697 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 36/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.6367e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.1562 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 37/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 4.5663e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9680 - val_loss: 0.1601 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 38/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 1.0399e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.1608 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 39/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 2.1326e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.1719 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 40/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.9877e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.1757 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 41/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9999 - loss: 8.2672e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9680 - val_loss: 0.1924 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 42/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 3.4379e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9680 - val_loss: 0.1954 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 43/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 3.2595e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9726 - val_loss: 0.1928 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 44/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 2.4800e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.1913 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 45/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 7.7926e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.1905 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 46/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 7.5313e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.1909 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 47/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 1.2346e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.1938 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 48/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 2.4802e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.1856 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 49/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 2.2706e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.1764 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 50/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.0530e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9589 - val_loss: 0.1794 - val_precision: 0.9589 - val_recall: 0.9589
# Epoch 51/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 4.8970e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9589 - val_loss: 0.1796 - val_precision: 0.9589 - val_recall: 0.9589
# Epoch 52/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 2.0513e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.1829 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 53/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 4.3881e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.1748 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 54/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9997 - loss: 6.2752e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9635 - val_loss: 0.2203 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 55/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9996 - loss: 0.0010 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9635 - val_loss: 0.2836 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 56/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.3520e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.2764 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 57/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 5.8376e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.2770 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 58/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 7.6373e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.2746 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 59/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.3908e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.2688 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 60/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 5.1116e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.2661 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 61/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 4.5179e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.2631 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 62/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.5368e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.2654 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 63/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.7785e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.2717 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 64/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 2.5097e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.2573 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 65/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 2.5319e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9635 - val_loss: 0.2710 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 66/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 4.5049e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9635 - val_loss: 0.2727 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 67/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 2.7297e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.2677 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 68/80
# 118/118 - 20s - 174ms/step - accuracy: 1.0000 - loss: 7.5125e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.2855 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 69/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.3361e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.3068 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 70/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 1.8691e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.3026 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 71/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 4.2846e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.2875 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 72/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.4359e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.2891 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 73/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9997 - loss: 6.2208e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9635 - val_loss: 0.2865 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 74/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.0752e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.2876 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 75/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.5337e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.2769 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 76/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.5170e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.2779 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 77/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.7838e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.2785 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 78/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 9.6563e-06 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.2777 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 79/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 9.9932e-06 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.2787 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 80/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 6.3207e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.2807 - val_precision: 0.9635 - val_recall: 0.9635
#
# Model saved in: /kaggle/working/model_mblf_mobilenetv2_20241209_200906_fold1.keras
# History saved in: /kaggle/working/history_mblf_mobilenetv2_20241209_200906_fold1.csv
#
#               precision    recall  f1-score   support
#
# Disease Free       1.00      1.00      1.00        88
#    Leaf Rust       0.96      0.98      0.97        98
#    Leaf Spot       0.94      0.88      0.91        33
#
#     accuracy                           0.97       219
#    macro avg       0.97      0.95      0.96       219
# weighted avg       0.97      0.97      0.97       219
#
#
# ================================================================================
# Fold #2
# ================================================================================
# Extracted fold2 from /kaggle/input/mblf-dataprep/data/fold2.zip
# Found 7512 files belonging to 3 classes.
# Found 218 files belonging to 3 classes.
# Epoch 1/80
# 118/118 - 99s - 836ms/step - accuracy: 0.8064 - loss: 0.4950 - precision: 0.8312 - recall: 0.7800 - val_accuracy: 0.7706 - val_loss: 0.5531 - val_precision: 0.7778 - val_recall: 0.7706
# Epoch 2/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9641 - loss: 0.1099 - precision: 0.9668 - recall: 0.9622 - val_accuracy: 0.7982 - val_loss: 0.5414 - val_precision: 0.8056 - val_recall: 0.7982
# Epoch 3/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9824 - loss: 0.0556 - precision: 0.9840 - recall: 0.9815 - val_accuracy: 0.8578 - val_loss: 0.3634 - val_precision: 0.8578 - val_recall: 0.8578
# Epoch 4/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9912 - loss: 0.0299 - precision: 0.9919 - recall: 0.9907 - val_accuracy: 0.8899 - val_loss: 0.3218 - val_precision: 0.8899 - val_recall: 0.8899
# Epoch 5/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9955 - loss: 0.0183 - precision: 0.9960 - recall: 0.9951 - val_accuracy: 0.9220 - val_loss: 0.2406 - val_precision: 0.9220 - val_recall: 0.9220
# Epoch 6/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9980 - loss: 0.0124 - precision: 0.9981 - recall: 0.9977 - val_accuracy: 0.9358 - val_loss: 0.2247 - val_precision: 0.9358 - val_recall: 0.9358
# Epoch 7/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9975 - loss: 0.0093 - precision: 0.9976 - recall: 0.9975 - val_accuracy: 0.9404 - val_loss: 0.1837 - val_precision: 0.9404 - val_recall: 0.9404
# Epoch 8/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9992 - loss: 0.0055 - precision: 0.9992 - recall: 0.9992 - val_accuracy: 0.9495 - val_loss: 0.1748 - val_precision: 0.9495 - val_recall: 0.9495
# Epoch 9/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9993 - loss: 0.0041 - precision: 0.9993 - recall: 0.9993 - val_accuracy: 0.9495 - val_loss: 0.1504 - val_precision: 0.9495 - val_recall: 0.9495
# Epoch 10/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9993 - loss: 0.0046 - precision: 0.9993 - recall: 0.9993 - val_accuracy: 0.9587 - val_loss: 0.1398 - val_precision: 0.9587 - val_recall: 0.9587
# Epoch 11/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9992 - loss: 0.0038 - precision: 0.9992 - recall: 0.9991 - val_accuracy: 0.9633 - val_loss: 0.1228 - val_precision: 0.9633 - val_recall: 0.9633
# Epoch 12/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9995 - loss: 0.0030 - precision: 0.9995 - recall: 0.9995 - val_accuracy: 0.9633 - val_loss: 0.1040 - val_precision: 0.9633 - val_recall: 0.9633
# Epoch 13/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9997 - loss: 0.0019 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9633 - val_loss: 0.1042 - val_precision: 0.9633 - val_recall: 0.9633
# Epoch 14/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9997 - loss: 0.0020 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9679 - val_loss: 0.1086 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 15/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 0.0015 - precision: 1.0000 - recall: 0.9999 - val_accuracy: 0.9679 - val_loss: 0.1002 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 16/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9996 - loss: 0.0020 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9725 - val_loss: 0.0923 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 17/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 9.6738e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0930 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 18/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9995 - loss: 0.0019 - precision: 0.9995 - recall: 0.9995 - val_accuracy: 0.9725 - val_loss: 0.0927 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 19/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 0.0012 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.0943 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 20/80
# 118/118 - 20s - 173ms/step - accuracy: 0.9999 - loss: 8.3584e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.0860 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 21/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 7.1595e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0788 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 22/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9997 - loss: 0.0010 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9725 - val_loss: 0.0815 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 23/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9996 - loss: 0.0014 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9679 - val_loss: 0.0870 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 24/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9995 - loss: 0.0017 - precision: 0.9995 - recall: 0.9995 - val_accuracy: 0.9725 - val_loss: 0.0712 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 25/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 5.2579e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.0726 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 26/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 5.2132e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0811 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 27/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 4.6175e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.0760 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 28/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 4.1943e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.0781 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 29/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 5.6207e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9679 - val_loss: 0.0942 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 30/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.7974e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.0838 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 31/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 4.2106e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.0796 - val_precision: 0.9724 - val_recall: 0.9679
# Epoch 32/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 2.2744e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.0774 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 33/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.4195e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.0786 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 34/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 3.9344e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.0851 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 35/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 5.0476e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.0754 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 36/80
# 118/118 - 12s - 102ms/step - accuracy: 0.9997 - loss: 5.4209e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9771 - val_loss: 0.0633 - val_precision: 0.9770 - val_recall: 0.9725
# Epoch 37/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.8690e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0569 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 38/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 3.5114e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.0616 - val_precision: 0.9770 - val_recall: 0.9725
# Epoch 39/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 3.3339e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9679 - val_loss: 0.0877 - val_precision: 0.9724 - val_recall: 0.9679
# Epoch 40/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.8484e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.0846 - val_precision: 0.9724 - val_recall: 0.9679
# Epoch 41/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.3134e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0823 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 42/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.0064e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0820 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 43/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9997 - loss: 7.4257e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9725 - val_loss: 0.0879 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 44/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9996 - loss: 0.0012 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9771 - val_loss: 0.0604 - val_precision: 0.9816 - val_recall: 0.9771
# Epoch 45/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 5.5679e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.0950 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 46/80
# 118/118 - 20s - 173ms/step - accuracy: 0.9995 - loss: 0.0021 - precision: 0.9995 - recall: 0.9995 - val_accuracy: 0.9725 - val_loss: 0.0827 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 47/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.2178e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0720 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 48/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 6.9882e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0626 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 49/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.1638e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0604 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 50/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 9.9057e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0627 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 51/80
# 118/118 - 12s - 100ms/step - accuracy: 1.0000 - loss: 1.2236e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0732 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 52/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.1127e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0713 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 53/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 4.6627e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0678 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 54/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.5414e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0707 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 55/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 9.8050e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0706 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 56/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 9.4290e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0648 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 57/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 7.1010e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0660 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 58/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.6280e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0686 - val_precision: 0.9862 - val_recall: 0.9817
# Epoch 59/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.9758e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0706 - val_precision: 0.9862 - val_recall: 0.9817
# Epoch 60/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 1.0142e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0699 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 61/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 4.0275e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0733 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 62/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.4228e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0812 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 63/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.1344e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1033 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 64/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.8919e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0480 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 65/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.3609e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0862 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 66/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 2.2839e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.1491 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 67/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.1302e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1551 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 68/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 8.7437e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1160 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 69/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 4.4207e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1169 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 70/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 2.9008e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1142 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 71/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.2806e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1292 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 72/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 9.4114e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1105 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 73/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9997 - loss: 0.0010 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9771 - val_loss: 0.1372 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 74/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.6241e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1413 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 75/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9996 - loss: 7.7782e-04 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9771 - val_loss: 0.1282 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 76/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.4331e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1663 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 77/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 8.9643e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1436 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 78/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 6.5702e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1583 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 79/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.6213e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1503 - val_precision: 0.9770 - val_recall: 0.9725
# Epoch 80/80
# 118/118 - 20s - 174ms/step - accuracy: 1.0000 - loss: 3.7214e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1561 - val_precision: 0.9725 - val_recall: 0.9725
#
# Model saved in: /kaggle/working/model_mblf_mobilenetv2_20241209_200906_fold2.keras
# History saved in: /kaggle/working/history_mblf_mobilenetv2_20241209_200906_fold2.csv
#
#               precision    recall  f1-score   support
#
# Disease Free       0.99      1.00      0.99        88
#    Leaf Rust       0.99      0.98      0.98        98
#    Leaf Spot       0.94      0.94      0.94        32
#
#     accuracy                           0.98       218
#    macro avg       0.97      0.97      0.97       218
# weighted avg       0.98      0.98      0.98       218
#
#
# ================================================================================
# Fold #3
# ================================================================================
# Extracted fold3 from /kaggle/input/mblf-dataprep/data/fold3.zip
# Found 7512 files belonging to 3 classes.
# Found 218 files belonging to 3 classes.
# Epoch 1/80
# 118/118 - 88s - 744ms/step - accuracy: 0.8079 - loss: 0.5010 - precision: 0.8286 - recall: 0.7833 - val_accuracy: 0.6422 - val_loss: 0.8799 - val_precision: 0.6465 - val_recall: 0.6376
# Epoch 2/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9606 - loss: 0.1150 - precision: 0.9644 - recall: 0.9579 - val_accuracy: 0.7156 - val_loss: 0.6971 - val_precision: 0.7143 - val_recall: 0.7110
# Epoch 3/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9814 - loss: 0.0588 - precision: 0.9824 - recall: 0.9800 - val_accuracy: 0.7844 - val_loss: 0.5622 - val_precision: 0.7844 - val_recall: 0.7844
# Epoch 4/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9912 - loss: 0.0308 - precision: 0.9920 - recall: 0.9911 - val_accuracy: 0.8486 - val_loss: 0.4079 - val_precision: 0.8525 - val_recall: 0.8486
# Epoch 5/80
# 118/118 - 12s - 102ms/step - accuracy: 0.9936 - loss: 0.0217 - precision: 0.9943 - recall: 0.9932 - val_accuracy: 0.8853 - val_loss: 0.3096 - val_precision: 0.8848 - val_recall: 0.8807
# Epoch 6/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9960 - loss: 0.0145 - precision: 0.9961 - recall: 0.9960 - val_accuracy: 0.9037 - val_loss: 0.2650 - val_precision: 0.9078 - val_recall: 0.9037
# Epoch 7/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9988 - loss: 0.0088 - precision: 0.9988 - recall: 0.9985 - val_accuracy: 0.9450 - val_loss: 0.1782 - val_precision: 0.9450 - val_recall: 0.9450
# Epoch 8/80
# 118/118 - 12s - 102ms/step - accuracy: 0.9985 - loss: 0.0070 - precision: 0.9985 - recall: 0.9985 - val_accuracy: 0.9495 - val_loss: 0.1706 - val_precision: 0.9495 - val_recall: 0.9495
# Epoch 9/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9992 - loss: 0.0046 - precision: 0.9992 - recall: 0.9992 - val_accuracy: 0.9633 - val_loss: 0.1142 - val_precision: 0.9631 - val_recall: 0.9587
# Epoch 10/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9991 - loss: 0.0051 - precision: 0.9991 - recall: 0.9989 - val_accuracy: 0.9633 - val_loss: 0.1087 - val_precision: 0.9633 - val_recall: 0.9633
# Epoch 11/80
# 118/118 - 20s - 174ms/step - accuracy: 0.9992 - loss: 0.0043 - precision: 0.9992 - recall: 0.9992 - val_accuracy: 0.9633 - val_loss: 0.0820 - val_precision: 0.9677 - val_recall: 0.9633
# Epoch 12/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9993 - loss: 0.0031 - precision: 0.9993 - recall: 0.9993 - val_accuracy: 0.9725 - val_loss: 0.0789 - val_precision: 0.9724 - val_recall: 0.9679
# Epoch 13/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 0.0020 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.0698 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 14/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9992 - loss: 0.0033 - precision: 0.9992 - recall: 0.9992 - val_accuracy: 0.9862 - val_loss: 0.0433 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 15/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9996 - loss: 0.0018 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9862 - val_loss: 0.0461 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 16/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9997 - loss: 0.0021 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9771 - val_loss: 0.0672 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 17/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9996 - loss: 0.0017 - precision: 0.9997 - recall: 0.9996 - val_accuracy: 0.9771 - val_loss: 0.0616 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 18/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9997 - loss: 0.0012 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9817 - val_loss: 0.0569 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 19/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 0.0010 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.0546 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 20/80
# 118/118 - 12s - 102ms/step - accuracy: 0.9999 - loss: 8.5832e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9908 - val_loss: 0.0511 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 21/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9997 - loss: 0.0013 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9908 - val_loss: 0.0540 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 22/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9996 - loss: 0.0011 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9908 - val_loss: 0.0568 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 23/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9996 - loss: 0.0012 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9908 - val_loss: 0.0580 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 24/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 6.0448e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0503 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 25/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 5.7333e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9908 - val_loss: 0.0465 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 26/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 6.1058e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9908 - val_loss: 0.0428 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 27/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 5.0698e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0453 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 28/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 4.9575e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0461 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 29/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 3.2854e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0444 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 30/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 4.7977e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9908 - val_loss: 0.0427 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 31/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9993 - loss: 0.0012 - precision: 0.9993 - recall: 0.9993 - val_accuracy: 0.9908 - val_loss: 0.0414 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 32/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 3.9011e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.0389 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 33/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 3.4784e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9862 - val_loss: 0.0365 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 34/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9999 - loss: 3.5978e-04 - precision: 1.0000 - recall: 0.9999 - val_accuracy: 0.9908 - val_loss: 0.0347 - val_precision: 0.9954 - val_recall: 0.9908
# Epoch 35/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 2.6292e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0357 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 36/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.8929e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.0430 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 37/80
# 118/118 - 21s - 174ms/step - accuracy: 1.0000 - loss: 1.8136e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.0433 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 38/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 4.3424e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9862 - val_loss: 0.0505 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 39/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.2805e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.0482 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 40/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 9.2312e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.0469 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 41/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.7813e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0412 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 42/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 3.8791e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9908 - val_loss: 0.0397 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 43/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9999 - loss: 5.1730e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9908 - val_loss: 0.0433 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 44/80
# 118/118 - 12s - 103ms/step - accuracy: 1.0000 - loss: 2.7353e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9954 - val_loss: 0.0530 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 45/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 1.3695e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9954 - val_loss: 0.0456 - val_precision: 0.9954 - val_recall: 0.9954
# Epoch 46/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9996 - loss: 9.4411e-04 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9908 - val_loss: 0.0442 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 47/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9995 - loss: 0.0044 - precision: 0.9995 - recall: 0.9995 - val_accuracy: 0.9908 - val_loss: 0.0843 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 48/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9999 - loss: 5.0575e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9908 - val_loss: 0.0618 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 49/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 1.3127e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0606 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 50/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9999 - loss: 5.5769e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9908 - val_loss: 0.0649 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 51/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9999 - loss: 7.6362e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9908 - val_loss: 0.0821 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 52/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.3400e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0797 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 53/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 3.4415e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0870 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 54/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 9.0622e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0854 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 55/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 8.5665e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0794 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 56/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 1.0655e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0789 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 57/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 4.3079e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0770 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 58/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 7.2038e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0710 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 59/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 5.6103e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0700 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 60/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 1.3094e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0674 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 61/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 1.0905e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0723 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 62/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 4.8829e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0699 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 63/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 4.1849e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0659 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 64/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 5.6329e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0644 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 65/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 1.7369e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0638 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 66/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 2.5811e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0637 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 67/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 8.0243e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0614 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 68/80
# 118/118 - 11s - 97ms/step - accuracy: 1.0000 - loss: 4.9352e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0603 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 69/80
# ...
# Epoch 4/80
# 118/118 - 12s - 103ms/step - accuracy: 0.9914 - loss: 0.0290 - precision: 0.9920 - recall: 0.9910 - val_accuracy: 0.9495 - val_loss: 0.1437 - val_precision: 0.9495 - val_recall: 0.9495
# Epoch 5/80
# 118/118 - 20s - 173ms/step - accuracy: 0.9944 - loss: 0.0202 - precision: 0.9949 - recall: 0.9941 - val_accuracy: 0.9541 - val_loss: 0.1275 - val_precision: 0.9585 - val_recall: 0.9541
# Epoch 6/80
# 118/118 - 12s - 102ms/step - accuracy: 0.9984 - loss: 0.0104 - precision: 0.9985 - recall: 0.9981 - val_accuracy: 0.9587 - val_loss: 0.1201 - val_precision: 0.9587 - val_recall: 0.9587
# Epoch 7/80
# 118/118 - 12s - 102ms/step - accuracy: 0.9977 - loss: 0.0100 - precision: 0.9979 - recall: 0.9977 - val_accuracy: 0.9633 - val_loss: 0.1192 - val_precision: 0.9633 - val_recall: 0.9633
# Epoch 8/80
# 118/118 - 11s - 97ms/step - accuracy: 0.9988 - loss: 0.0068 - precision: 0.9988 - recall: 0.9988 - val_accuracy: 0.9633 - val_loss: 0.1136 - val_precision: 0.9633 - val_recall: 0.9633
# Epoch 9/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9995 - loss: 0.0043 - precision: 0.9995 - recall: 0.9995 - val_accuracy: 0.9633 - val_loss: 0.1114 - val_precision: 0.9633 - val_recall: 0.9633
# Epoch 10/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9992 - loss: 0.0043 - precision: 0.9993 - recall: 0.9991 - val_accuracy: 0.9633 - val_loss: 0.1075 - val_precision: 0.9633 - val_recall: 0.9633
# Epoch 11/80
# 118/118 - 12s - 102ms/step - accuracy: 0.9988 - loss: 0.0035 - precision: 0.9988 - recall: 0.9988 - val_accuracy: 0.9679 - val_loss: 0.1119 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 12/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9991 - loss: 0.0042 - precision: 0.9991 - recall: 0.9989 - val_accuracy: 0.9679 - val_loss: 0.1093 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 13/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9991 - loss: 0.0029 - precision: 0.9991 - recall: 0.9991 - val_accuracy: 0.9679 - val_loss: 0.1118 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 14/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 0.0014 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.1107 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 15/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9996 - loss: 0.0018 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9679 - val_loss: 0.1134 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 16/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 0.0016 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9679 - val_loss: 0.1185 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 17/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 0.0011 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.1244 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 18/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9997 - loss: 0.0020 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9679 - val_loss: 0.1249 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 19/80
# 118/118 - 12s - 102ms/step - accuracy: 0.9997 - loss: 0.0018 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9725 - val_loss: 0.1216 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 20/80
# 118/118 - 20s - 167ms/step - accuracy: 1.0000 - loss: 7.0743e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.1268 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 21/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 7.1326e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.1326 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 22/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9999 - loss: 0.0013 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.1297 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 23/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9997 - loss: 9.2585e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9771 - val_loss: 0.1331 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 24/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 5.2784e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.1340 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 25/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9999 - loss: 6.5612e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.1371 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 26/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 7.9854e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.1390 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 27/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 3.5835e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1458 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 28/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.5106e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1492 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 29/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.5320e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1486 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 30/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 2.6969e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1479 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 31/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 3.7641e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9771 - val_loss: 0.1519 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 32/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.3816e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1565 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 33/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 2.0740e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1513 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 34/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.4893e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1518 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 35/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 1.3000e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1551 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 36/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 1.9964e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1559 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 37/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.8063e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1572 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 38/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 2.3071e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1390 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 39/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.4865e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1319 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 40/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.6157e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1408 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 41/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.1425e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1405 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 42/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.1808e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1403 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 43/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 8.3553e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1476 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 44/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 5.9385e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1501 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 45/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.0417e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1524 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 46/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 6.9370e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1545 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 47/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 5.8926e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1483 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 48/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 6.3933e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1493 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 49/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 4.2240e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9771 - val_loss: 0.1509 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 50/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 8.9911e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1556 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 51/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 6.3760e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1538 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 52/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 6.1700e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1537 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 53/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 6.6321e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.1655 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 54/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 6.2242e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1641 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 55/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 7.6013e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1731 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 56/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.2747e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1522 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 57/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 3.7691e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1513 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 58/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.5714e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1504 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 59/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.6697e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1547 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 60/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 2.3528e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1415 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 61/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 5.2955e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1374 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 62/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 6.1398e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1400 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 63/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 7.1466e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.1407 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 64/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9996 - loss: 6.1211e-04 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9725 - val_loss: 0.1811 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 65/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.6634e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1677 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 66/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 1.5984e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.1228 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 67/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9997 - loss: 5.6930e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9771 - val_loss: 0.1893 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 68/80
# 118/118 - 12s - 102ms/step - accuracy: 0.9999 - loss: 7.1410e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9817 - val_loss: 0.1421 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 69/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9999 - loss: 5.0760e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9817 - val_loss: 0.1244 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 70/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 6.7841e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1123 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 71/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 3.2828e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.1014 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 72/80
# 118/118 - 11s - 97ms/step - accuracy: 0.9997 - loss: 0.0011 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9817 - val_loss: 0.0937 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 73/80
# 118/118 - 12s - 102ms/step - accuracy: 1.0000 - loss: 1.1957e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.1297 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 74/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 2.5828e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.1268 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 75/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 2.1650e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.1246 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 76/80
# 118/118 - 11s - 97ms/step - accuracy: 1.0000 - loss: 3.7899e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.1189 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 77/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 1.2582e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.1206 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 78/80
# 118/118 - 11s - 97ms/step - accuracy: 0.9999 - loss: 3.6641e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9817 - val_loss: 0.0901 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 79/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 9.1167e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0919 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 80/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 9.5606e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.1224 - val_precision: 0.9862 - val_recall: 0.9862
#
# Model saved in: /kaggle/working/model_mblf_mobilenetv2_20241209_200906_fold5.keras
# History saved in: /kaggle/working/history_mblf_mobilenetv2_20241209_200906_fold5.csv
#
#               precision    recall  f1-score   support
#
# Disease Free       1.00      1.00      1.00        88
#    Leaf Rust       0.98      0.99      0.98        97
#    Leaf Spot       0.97      0.94      0.95        33
#
#     accuracy                           0.99       218
#    macro avg       0.98      0.98      0.98       218
# weighted avg       0.99      0.99      0.99       218

# %% [markdown]
# # 4. Display Results

# %%
for idx in range(N_FOLDS):
    _fold_str = f'Fold #{idx+1}'

    # Print individual test results
    print(f'\nResults for {_fold_str}:')
    print('----------------------------------------')
    print(f'Loss       : {score_lst[idx][0]:.6f}')
    print(f'Accuracy   : {score_lst[idx][1]:.6f}')
    print(f'Precision  : {score_lst[idx][2]:.6f}')
    print(f'Recall     : {score_lst[idx][3]:.6f}')
    print(f'F1 Score   : {f1_lst[idx]:.6f}')

    # Plot individual training curves
    plt.figure(figsize=(20, 5))
    
    plt.subplot(1,2,1)
    plt.plot(df_lst[idx].loss, label='Training Loss')
    plt.plot(df_lst[idx].val_loss, label='Validation Loss')
    plt.title("Loss for "+_fold_str)
    plt.grid()
    plt.legend()
    plt.subplot(1,2,2)
    plt.plot(df_lst[idx].accuracy, label='Training Accuracy')
    plt.plot(df_lst[idx].val_accuracy, label='Validation Accuracy')
    plt.title("Accuracy for "+_fold_str)
    plt.grid()
    plt.legend()
    plt.show()
    
    # Plot individual confusion matrix
    cmd = ConfusionMatrixDisplay(cm_lst[idx], display_labels=DISPLAY_LABELS)
    cmd.plot(cmap='Blues')
    plt.show()
    
    # Plot ROC and AUC for each class
    cls_auc_lst = plot_roc_auc(all_y_true[idx], all_y_pred[idx], num_classes=3, display_labels=DISPLAY_LABELS, title=f'ROC Curve for Fold #{idx+1}')
    for i, cls_auc in enumerate(cls_auc_lst):
        print(f'AUC for {DISPLAY_LABELS[i]:<15}: {cls_auc:.6f}')
    
    print('')
    pass
# Out:
# Results for Fold #1:
# ----------------------------------------
# Loss       : 0.185683
# Accuracy   : 0.972603
# Precision  : 0.972603
# Recall     : 0.972603
# F1 Score   : 0.972603
# AUC for Disease Free   : 1.000000
# AUC for Leaf Rust      : 0.992579
# AUC for Leaf Spot      : 0.978983
#
#
# Results for Fold #2:
# ----------------------------------------
# Loss       : 0.073218
# Accuracy   : 0.981651
# Precision  : 0.981651
# Recall     : 0.981651
# F1 Score   : 0.981651
# AUC for Disease Free   : 0.999913
# AUC for Leaf Rust      : 0.999320
# AUC for Leaf Spot      : 0.998992
#
#
# Results for Fold #3:
# ----------------------------------------
# Loss       : 0.052977
# Accuracy   : 0.995413
# Precision  : 0.995413
# Recall     : 0.995413
# F1 Score   : 0.995413
# AUC for Disease Free   : 1.000000
# AUC for Leaf Rust      : 0.999320
# AUC for Leaf Spot      : 0.998992
#
#
# Results for Fold #4:
# ----------------------------------------
# Loss       : 0.043083
# Accuracy   : 0.995413
# Precision  : 0.995392
# Recall     : 0.990826
# F1 Score   : 0.995413
# AUC for Disease Free   : 1.000000
# AUC for Leaf Rust      : 0.998895
# AUC for Leaf Spot      : 0.998992
#
#
# Results for Fold #5:
# ----------------------------------------
# Loss       : 0.129651
# Accuracy   : 0.986239
# Precision  : 0.986239
# Recall     : 0.986239
# F1 Score   : 0.986239
# AUC for Disease Free   : 1.000000
# AUC for Leaf Rust      : 0.995825
# AUC for Leaf Spot      : 0.995332

# %%
# Aggregate results
avg_score = np.mean(score_lst, axis=0)
avg_f1 = np.mean(f1_lst, axis=0)
avg_df = reduce(lambda a, b: a.add(b, fill_value=0), df_lst) / 5.0
avg_cm = np.mean(cm_lst, axis=0)
all_y_true = np.concatenate(all_y_true, axis=0)
all_y_pred = np.concatenate(all_y_pred, axis=0)

# Print aggregated test results
print('Cross-Validation Results:')
print('----------------------------------------')
print(f'Average Loss       : {avg_score[0]:.6f}')
print(f'Average Accuracy   : {avg_score[1]:.6f}')
print(f'Average Precision  : {avg_score[2]:.6f}')
print(f'Average Recall     : {avg_score[3]:.6f}')
print(f'Average F1 Score   : {avg_f1:.6f}')

# Plot aggregated training curves
plt.figure(figsize=(10, 5))
plt.plot(avg_df.loss, label='Training Loss')
plt.plot(avg_df.val_loss, label='Validation Loss')
plt.title("Aggregated Loss")
plt.grid()
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(avg_df.accuracy, label='Training Accuracy')
plt.plot(avg_df.val_accuracy, label='Validation Accuracy')
plt.title("Aggregated Accuracy")
plt.grid()
plt.legend()
plt.show()

# Plot aggregated confusion matrix
cmd = ConfusionMatrixDisplay(avg_cm, display_labels=DISPLAY_LABELS)
cmd.plot(cmap='Blues')
plt.show()
# Out:
# Cross-Validation Results:
# ----------------------------------------
# Average Loss       : 0.096922
# Average Accuracy   : 0.986264
# Average Precision  : 0.986259
# Average Recall     : 0.985346
# Average F1 Score   : 0.986264

# %%
# Plot aggregated ROC, AUC
cls_auc_lst = plot_roc_auc(all_y_true, all_y_pred, num_classes=3, display_labels=DISPLAY_LABELS, title=f'ROC Curve')
for i, cls_auc in enumerate(cls_auc_lst):
    print(f'AUC for {DISPLAY_LABELS[i]:<15}: {cls_auc:.6f}')
# Out:
# AUC for Disease Free   : 0.999997
# AUC for Leaf Rust      : 0.996890
# AUC for Leaf Spot      : 0.994847
