# %% [markdown]
# # Mulberry Leaf: Cross-Validation on MobileNetV2
# ### ***Dataset: Mulberry Leaf Dataset https://www.kaggle.com/datasets/nahiduzzaman13/mulberry-leaf-dataset [MSR, Preprocessed]***

# %%
import pandas as pd
import numpy as np
import shutil
import zipfile
from functools import reduce
from datetime import datetime
from os import path, makedirs, remove, environ, listdir
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, f1_score, roc_curve, auc

import tensorflow as tf

# Set environment variable to suppress TensorFlow's lower-level logs
environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
tf.get_logger().setLevel('ERROR')

from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Dropout, Multiply, Activation, GlobalAveragePooling2D, Multiply, Reshape
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.metrics import Precision, Recall


from tensorflow.keras import mixed_precision
# Enable mixed precision
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)

plt.rcParams['font.family'] = 'serif'            # Use a specific font
plt.rcParams['font.size'] = 14                   # Set a general font size

# %%
def imshow(imgs, titles=None):
    '''Utility class for showing images.'''
    r, c = 3, 4
    plt.figure(figsize=(16, 12))
    for idx in range(1, min(r*c, len(imgs))+1):
        plt.subplot(r, c, idx)
        plt.axis('off')
        if titles != None and idx-1 < len(titles):
            plt.title(titles[idx-1])
        plt.imshow(imgs[idx-1], cmap='plasma')    
    plt.show()

def se_block(x, ratio=8):
    """Contains the implementation of Squeeze-and-Excitation(SE) block.
    As described in https://arxiv.org/abs/1709.01507.
    """
    num_channels = K.int_shape(x)[-1]

    se = GlobalAveragePooling2D(name='block_se_GAP')(x)
    se = Reshape((1, 1, num_channels), name='block_se_reshape')(se)
    se = Dense(num_channels // ratio, 
                      name='block_se_dense_1', 
                      activation='relu',
                      kernel_initializer='he_normal',
                      use_bias=True,
                      bias_initializer='zeros')(se)
    se = Dense(num_channels,
                      name='block_se_dense_2', 
                      activation='sigmoid',
                      kernel_initializer='he_normal',
                      use_bias=True,
                      bias_initializer='zeros')(se)

    return Multiply(name='block_se_multiply')([x, se])

def process_image(image, label):
    image = tf.cast(image/255. ,tf.float32)
    return image,label

def get_predictions(model, ds):
    y_true, y_pred = [], []
    for images, labels in ds:
        preds = model.predict(images, verbose=0)
        y_true.extend(labels.numpy())
        y_pred.extend(preds)

    true_labels = np.argmax(y_true, axis=1)
    pred_labels = np.argmax(y_pred, axis=1)
    
    return y_true, y_pred, true_labels, pred_labels

def plot_roc_auc(y_true, y_pred, num_classes, display_labels, title=None):
    class_auc_lst = []
    plt.figure(figsize=(10, 6))
    for i in range(num_classes):
        # One-vs-rest for class `i`
        y_true_class = [y[i] for y in y_true]
        y_pred_class = [y[i] for y in y_pred]
        
        fpr, tpr, _ = roc_curve(y_true_class, y_pred_class)
        class_auc = auc(fpr, tpr)
        class_auc_lst.append(class_auc)
        
        # Plot ROC curve for each class
        plt.plot(fpr, tpr, label=f'{display_labels[i]} (AUC = {class_auc:.4f})')
    
    # Finalize and display plot
    plt.plot([0, 1], [0, 1], color='r', linestyle='--', lw=2)
    plt.title('ROC Curve' if not title else title)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend(loc="lower right")
    plt.show()
    
    return class_auc_lst

# %% [markdown]
# # 1. Fetch Dataset

# %%
ROOT_INPUT_DIR = '/kaggle/input/mblf-dataprep/'
ROOT_OUTPUT_DIR = '/kaggle/working/'

NEW_DATA_DIR = path.join(ROOT_OUTPUT_DIR, 'data_msr')
TRAIN_DIR = path.join(ROOT_OUTPUT_DIR, 'data_msr/train')
TEST_DIR = path.join(ROOT_OUTPUT_DIR, 'data_msr/test')

IMG_SIZE = 224
BATCH_SIZE = 64
INPUT_SHAPE = (IMG_SIZE, IMG_SIZE, 3)
EPOCHS = 80
LEARNING_RATE = 2e-5

TIMESTAMP = datetime.now().strftime('%Y%m%d_%H%M%S')
N_FOLDS = 5
DISPLAY_LABELS = ['Disease Free', 'Leaf Rust', 'Leaf Spot']

# %%
## Fresh data from storage
#
# Clean up older files
_path_to_temp_model = path.join(ROOT_OUTPUT_DIR, 'model_temp.keras')
if path.exists(_path_to_temp_model):
    remove(_path_to_temp_model)
    print('Deleted:', _path_to_temp_model)

if path.exists(NEW_DATA_DIR):
    shutil.rmtree(NEW_DATA_DIR, ignore_errors=True)
    print('Deleted:', NEW_DATA_DIR)

# %% [markdown]
# # 2. Construct Model

# %%
def build_model_mobilenetv2(lr=LEARNING_RATE):
    # Load base model without the top layer
    base_model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE)
    # Add custom layers
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)
    x = Dense(128)(x)
    x = Dense(3)(x)  # 3 classes
    op = Activation('softmax', dtype='float32')(x)

    # Create the new model
    model = Model(name='MobileNetV2', inputs=base_model.input, outputs=op)
    
    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), 
        loss='categorical_crossentropy', 
        metrics=[
            'accuracy', 
            Precision(name='precision'), 
            Recall(name='recall')
        ]
    )

    return model

# %%
## Show summary

build_model_mobilenetv2().summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "MobileNetV2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 112, 112,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 112, 112,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 112, 112,  │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 112, 112,  │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 112, 112,  │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 112, 112,  │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 113, 113,  │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 56, 56,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 56, 56,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 56, 56,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 56, 56,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 56, 56,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 56, 56,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 56, 56,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 56, 56,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 56, 56,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 56, 56,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 56, 56,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 56, 56,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 56, 56,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 56, 56,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 56, 56,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 56, 56,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 56, 56,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 57, 57,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 28, 28,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 28, 28,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 28, 28,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 28, 28,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 28, 28,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 28, 28,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 28, 28,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 28, 28,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 28, 28,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 28, 28,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 28, 28,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 28, 28,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 28, 28,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 28, 28,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 28, 28,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 28, 28,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 28, 28,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 28, 28,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 28, 28,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 28, 28,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 28, 28,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 28, 28,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 28, 28,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 28, 28,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 28, 28,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 28, 28,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 29, 29,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 14, 14,    │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 14, 14,    │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 14, 14,    │          0 │ block_6_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 14, 14,    │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 14, 14,    │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 14, 14,    │     24,576 │ block_6_project_… │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 14, 14,    │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 14, 14,    │          0 │ block_7_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 14, 14,    │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 14, 14,    │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 14, 14,    │          0 │ block_7_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 14, 14,    │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 14, 14,    │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 14, 14,    │          0 │ block_6_project_… │
# │                     │ 64)               │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 14, 14,    │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 14, 14,    │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 14, 14,    │          0 │ block_8_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 14, 14,    │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 14, 14,    │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 14, 14,    │          0 │ block_8_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 14, 14,    │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 14, 14,    │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 14, 14,    │          0 │ block_7_add[0][0… │
# │                     │ 64)               │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 14, 14,    │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 14, 14,    │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 14, 14,    │          0 │ block_9_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 14, 14,    │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 14, 14,    │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 14, 14,    │          0 │ block_9_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 14, 14,    │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 14, 14,    │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 14, 14,    │          0 │ block_8_add[0][0… │
# │                     │ 64)               │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 14, 14,    │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 14, 14,    │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 14, 14,    │          0 │ block_10_expand_… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 14, 14,    │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 14, 14,    │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 14, 14,    │          0 │ block_10_depthwi… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 14, 14,    │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 14, 14,    │        384 │ block_10_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 14, 14,    │     55,296 │ block_10_project… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 14, 14,    │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 14, 14,    │          0 │ block_11_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 14, 14,    │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 14, 14,    │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 14, 14,    │          0 │ block_11_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 14, 14,    │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 14, 14,    │        384 │ block_11_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 14, 14,    │          0 │ block_10_project… │
# │                     │ 96)               │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 14, 14,    │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 14, 14,    │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 14, 14,    │          0 │ block_12_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 14, 14,    │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 14, 14,    │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 14, 14,    │          0 │ block_12_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 14, 14,    │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 14, 14,    │        384 │ block_12_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 14, 14,    │          0 │ block_11_add[0][… │
# │                     │ 96)               │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 14, 14,    │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 14, 14,    │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 14, 14,    │          0 │ block_13_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 15, 15,    │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 7, 7, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 7, 7, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 7, 7, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 7, 7, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 7, 7, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 7, 7, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 7, 7, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 7, 7, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 7, 7, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 7, 7, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 7, 7, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 7, 7, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 7, 7, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 7, 7, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 7, 7, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 7, 7, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 7, 7, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 7, 7, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 7, 7, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 7, 7, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 7, 7, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 7, 7, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 7, 7, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 7, 7, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 7, 7, 320) │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 7, 7,      │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 7, 7,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 7, 7,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    163,968 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 3)         │        387 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 3)         │          0 │ dense_1[0][0]     │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,422,339 (9.24 MB)
#  Trainable params: 2,388,227 (9.11 MB)
#  Non-trainable params: 34,112 (133.25 KB)

# %% [markdown]
# # 3. Train & Evaluate

# %%
score_lst = []
df_lst = []
cm_lst = []
f1_lst = []
all_y_true = []
all_y_pred = []

for i in range(N_FOLDS):
    print('================================================================================')
    print(f'Fold #{i+1}')
    print('================================================================================')
    _fold_str = f'fold{i+1}'
    
    # Unzipping
    _path_to_zip_file = path.join(
        ROOT_INPUT_DIR, 'data_msr', _fold_str+'.zip'
    )
    makedirs(NEW_DATA_DIR, exist_ok=True)
    with zipfile.ZipFile(_path_to_zip_file, 'r') as zip_ref:
        zip_ref.extractall(NEW_DATA_DIR)
        print(f'Extracted {_fold_str} from {_path_to_zip_file}')
    
    # Prepare tensorflow datasets
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        TRAIN_DIR,
        color_mode='rgb',
        seed=1234, 
        label_mode="categorical", 
        image_size=(IMG_SIZE, IMG_SIZE), 
        batch_size=BATCH_SIZE
    )
    test_ds = tf.keras.preprocessing.image_dataset_from_directory(
        TEST_DIR,
        color_mode='rgb',
        seed=1234, 
        label_mode="categorical", 
        image_size=(IMG_SIZE, IMG_SIZE), 
        batch_size=BATCH_SIZE
    )
    train_ds = train_ds.map(process_image)
    test_ds = test_ds.map(process_image)

    # Compile model
    model = build_model_mobilenetv2()
    
    # Training
    cb = [
        ModelCheckpoint(filepath=path.join(ROOT_OUTPUT_DIR, 'model_temp.keras'), monitor='val_accuracy', mode='max', save_best_only=True)
    ]
    history = model.fit(train_ds, callbacks=cb, validation_data=test_ds, epochs=EPOCHS, verbose=2)
    
    # Saving
    MODEL_SAVE_PATH = path.join(ROOT_OUTPUT_DIR, f'model_mblf_mobilenetv2_msr_{TIMESTAMP}_{_fold_str}.keras')
    HISTORY_SAVE_PATH = path.join(ROOT_OUTPUT_DIR, f'history_mblf_mobilenetv2_msr_{TIMESTAMP}_{_fold_str}.csv')
    shutil.move(path.join(ROOT_OUTPUT_DIR, 'model_temp.keras'), MODEL_SAVE_PATH)
    print('\nModel saved in:', MODEL_SAVE_PATH)
    
    # Save the history to a CSV file
    df = pd.DataFrame(history.history)
    df_lst.append(df)
    df.to_csv(HISTORY_SAVE_PATH)
    print('History saved in:', HISTORY_SAVE_PATH)
    print('')

    # Load again and evaluate
    saved_model = load_model(MODEL_SAVE_PATH)
    score = saved_model.evaluate(test_ds, verbose=0)
    score_lst.append(score)

    # Confusion matrix + F1 Score + AUC-ROC
    y_true, y_pred, true_labels, pred_labels = get_predictions(model=saved_model, ds=test_ds)
    
    cf_matrix = confusion_matrix(true_labels, pred_labels)
    cm_lst.append(cf_matrix)
    f1 = f1_score(true_labels, pred_labels, average='micro')
    f1_lst.append(f1)
    all_y_true.append(y_true)
    all_y_pred.append(y_pred)
    
    print(classification_report(true_labels, pred_labels, target_names=DISPLAY_LABELS))
    print('')
    
    # Cleaning
    shutil.rmtree(NEW_DATA_DIR)
    pass
# Out:
# ================================================================================
# Fold #1
# ================================================================================
# Extracted fold1 from /kaggle/input/mblf-dataprep/data_msr/fold1.zip
# Found 7517 files belonging to 3 classes.
# Found 219 files belonging to 3 classes.
# Epoch 1/80
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733768563.313582      63 service.cc:145] XLA service 0x7f4a5c01b530 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733768563.313679      63 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1733768600.273085      63 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 118/118 - 113s - 955ms/step - accuracy: 0.7935 - loss: 0.5321 - precision: 0.8174 - recall: 0.7645 - val_accuracy: 0.7945 - val_loss: 0.5901 - val_precision: 0.8028 - val_recall: 0.7808
# Epoch 2/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9605 - loss: 0.1081 - precision: 0.9641 - recall: 0.9580 - val_accuracy: 0.8082 - val_loss: 0.5635 - val_precision: 0.8157 - val_recall: 0.8082
# Epoch 3/80
# 118/118 - 12s - 99ms/step - accuracy: 0.9848 - loss: 0.0497 - precision: 0.9853 - recall: 0.9842 - val_accuracy: 0.8311 - val_loss: 0.5423 - val_precision: 0.8387 - val_recall: 0.8311
# Epoch 4/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9920 - loss: 0.0282 - precision: 0.9927 - recall: 0.9910 - val_accuracy: 0.8630 - val_loss: 0.4607 - val_precision: 0.8670 - val_recall: 0.8630
# Epoch 5/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9953 - loss: 0.0184 - precision: 0.9956 - recall: 0.9952 - val_accuracy: 0.8721 - val_loss: 0.4567 - val_precision: 0.8721 - val_recall: 0.8721
# Epoch 6/80
# 118/118 - 12s - 99ms/step - accuracy: 0.9967 - loss: 0.0131 - precision: 0.9971 - recall: 0.9963 - val_accuracy: 0.8858 - val_loss: 0.3935 - val_precision: 0.8899 - val_recall: 0.8858
# Epoch 7/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9975 - loss: 0.0102 - precision: 0.9976 - recall: 0.9975 - val_accuracy: 0.9041 - val_loss: 0.3546 - val_precision: 0.9083 - val_recall: 0.9041
# Epoch 8/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9991 - loss: 0.0054 - precision: 0.9991 - recall: 0.9989 - val_accuracy: 0.9132 - val_loss: 0.3204 - val_precision: 0.9259 - val_recall: 0.9132
# Epoch 9/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9995 - loss: 0.0051 - precision: 0.9995 - recall: 0.9993 - val_accuracy: 0.9315 - val_loss: 0.2937 - val_precision: 0.9312 - val_recall: 0.9269
# Epoch 10/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9997 - loss: 0.0034 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9361 - val_loss: 0.2626 - val_precision: 0.9361 - val_recall: 0.9361
# Epoch 11/80
# 118/118 - 12s - 99ms/step - accuracy: 0.9993 - loss: 0.0035 - precision: 0.9993 - recall: 0.9992 - val_accuracy: 0.9406 - val_loss: 0.2642 - val_precision: 0.9406 - val_recall: 0.9406
# Epoch 12/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9991 - loss: 0.0049 - precision: 0.9991 - recall: 0.9991 - val_accuracy: 0.9543 - val_loss: 0.2137 - val_precision: 0.9543 - val_recall: 0.9543
# Epoch 13/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9992 - loss: 0.0034 - precision: 0.9993 - recall: 0.9992 - val_accuracy: 0.9589 - val_loss: 0.2114 - val_precision: 0.9589 - val_recall: 0.9589
# Epoch 14/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9996 - loss: 0.0023 - precision: 0.9996 - recall: 0.9995 - val_accuracy: 0.9452 - val_loss: 0.2419 - val_precision: 0.9495 - val_recall: 0.9452
# Epoch 15/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9997 - loss: 0.0019 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9498 - val_loss: 0.2343 - val_precision: 0.9498 - val_recall: 0.9498
# Epoch 16/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9992 - loss: 0.0026 - precision: 0.9992 - recall: 0.9992 - val_accuracy: 0.9406 - val_loss: 0.2324 - val_precision: 0.9406 - val_recall: 0.9406
# Epoch 17/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9997 - loss: 0.0015 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9406 - val_loss: 0.2176 - val_precision: 0.9450 - val_recall: 0.9406
# Epoch 18/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 9.0145e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9543 - val_loss: 0.2178 - val_precision: 0.9543 - val_recall: 0.9543
# Epoch 19/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9997 - loss: 9.8011e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9543 - val_loss: 0.2094 - val_precision: 0.9543 - val_recall: 0.9543
# Epoch 20/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9999 - loss: 6.2129e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9589 - val_loss: 0.2014 - val_precision: 0.9587 - val_recall: 0.9543
# Epoch 21/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9999 - loss: 7.1117e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9635 - val_loss: 0.1932 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 22/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9999 - loss: 8.5754e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9635 - val_loss: 0.1885 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 23/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9999 - loss: 6.0826e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9589 - val_loss: 0.1887 - val_precision: 0.9589 - val_recall: 0.9589
# Epoch 24/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9999 - loss: 6.8107e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9680 - val_loss: 0.1866 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 25/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 3.4586e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.1909 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 26/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9997 - loss: 0.0012 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9589 - val_loss: 0.1979 - val_precision: 0.9589 - val_recall: 0.9589
# Epoch 27/80
# 118/118 - 12s - 100ms/step - accuracy: 1.0000 - loss: 4.6011e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.1975 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 28/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 7.4026e-04 - precision: 1.0000 - recall: 0.9999 - val_accuracy: 0.9635 - val_loss: 0.1944 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 29/80
# 118/118 - 12s - 99ms/step - accuracy: 1.0000 - loss: 2.8724e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9772 - val_loss: 0.1943 - val_precision: 0.9772 - val_recall: 0.9772
# Epoch 30/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 2.7609e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9772 - val_loss: 0.1957 - val_precision: 0.9772 - val_recall: 0.9772
# Epoch 31/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9999 - loss: 4.7361e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9772 - val_loss: 0.1986 - val_precision: 0.9772 - val_recall: 0.9772
# Epoch 32/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9997 - loss: 4.9711e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9726 - val_loss: 0.2094 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 33/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 5.2233e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9726 - val_loss: 0.2066 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 34/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 4.0684e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.2096 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 35/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.4034e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.2157 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 36/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9996 - loss: 8.4109e-04 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9680 - val_loss: 0.2114 - val_precision: 0.9725 - val_recall: 0.9680
# Epoch 37/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 2.4661e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.2139 - val_precision: 0.9725 - val_recall: 0.9680
# Epoch 38/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9997 - loss: 5.5142e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9726 - val_loss: 0.2149 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 39/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9997 - loss: 4.8307e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9726 - val_loss: 0.2452 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 40/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9999 - loss: 2.7651e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9726 - val_loss: 0.2128 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 41/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.4376e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9772 - val_loss: 0.2089 - val_precision: 0.9772 - val_recall: 0.9772
# Epoch 42/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 2.5617e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.2281 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 43/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 1.6543e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.2180 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 44/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.8411e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.2173 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 45/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9999 - loss: 2.9050e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9635 - val_loss: 0.2542 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 46/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9999 - loss: 3.2348e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9543 - val_loss: 0.2684 - val_precision: 0.9543 - val_recall: 0.9543
# Epoch 47/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 1.8692e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9543 - val_loss: 0.2604 - val_precision: 0.9543 - val_recall: 0.9543
# Epoch 48/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 1.4364e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9543 - val_loss: 0.2649 - val_precision: 0.9543 - val_recall: 0.9543
# Epoch 49/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 1.0952e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.2541 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 50/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 6.5562e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.2534 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 51/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 6.5589e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9635 - val_loss: 0.2522 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 52/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 1.0330e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.2568 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 53/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.1287e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.2539 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 54/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 3.9973e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.2543 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 55/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 4.2375e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9772 - val_loss: 0.2539 - val_precision: 0.9772 - val_recall: 0.9772
# Epoch 56/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9997 - loss: 3.9341e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9772 - val_loss: 0.2521 - val_precision: 0.9772 - val_recall: 0.9772
# Epoch 57/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 3.0623e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9772 - val_loss: 0.2520 - val_precision: 0.9772 - val_recall: 0.9772
# Epoch 58/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.5147e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9772 - val_loss: 0.2532 - val_precision: 0.9772 - val_recall: 0.9772
# Epoch 59/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9997 - loss: 3.6247e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9772 - val_loss: 0.2330 - val_precision: 0.9772 - val_recall: 0.9772
# Epoch 60/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 6.4979e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.2398 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 61/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9999 - loss: 2.9291e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9726 - val_loss: 0.2559 - val_precision: 0.9771 - val_recall: 0.9726
# Epoch 62/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9995 - loss: 0.0015 - precision: 0.9995 - recall: 0.9995 - val_accuracy: 0.9726 - val_loss: 0.2593 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 63/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 1.8288e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.2840 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 64/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.6307e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.2980 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 65/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9996 - loss: 4.8181e-04 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9726 - val_loss: 0.2618 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 66/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9999 - loss: 2.9509e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9726 - val_loss: 0.2692 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 67/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 2.2017e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9772 - val_loss: 0.2319 - val_precision: 0.9772 - val_recall: 0.9772
# Epoch 68/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9999 - loss: 4.2541e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9726 - val_loss: 0.2306 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 69/80
# 118/118 - 11s - 93ms/step - accuracy: 0.9997 - loss: 4.0412e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9680 - val_loss: 0.2716 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 70/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.1174e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9680 - val_loss: 0.2691 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 71/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 1.8475e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.2608 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 72/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 1.4658e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9772 - val_loss: 0.2690 - val_precision: 0.9772 - val_recall: 0.9772
# Epoch 73/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 2.5159e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9726 - val_loss: 0.2507 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 74/80
# 118/118 - 20s - 173ms/step - accuracy: 1.0000 - loss: 1.9522e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.2531 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 75/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 4.0069e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9726 - val_loss: 0.2402 - val_precision: 0.9726 - val_recall: 0.9726
# Epoch 76/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 1.8104e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9772 - val_loss: 0.2429 - val_precision: 0.9772 - val_recall: 0.9772
# Epoch 77/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 2.0611e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9772 - val_loss: 0.2451 - val_precision: 0.9772 - val_recall: 0.9772
# Epoch 78/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 2.4920e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9772 - val_loss: 0.2480 - val_precision: 0.9772 - val_recall: 0.9772
# Epoch 79/80
# 118/118 - 11s - 93ms/step - accuracy: 1.0000 - loss: 1.6301e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9772 - val_loss: 0.2494 - val_precision: 0.9772 - val_recall: 0.9772
# Epoch 80/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.4407e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9772 - val_loss: 0.2517 - val_precision: 0.9772 - val_recall: 0.9772
#
# Model saved in: /kaggle/working/model_mblf_mobilenetv2_msr_20241209_182206_fold1.keras
# History saved in: /kaggle/working/history_mblf_mobilenetv2_msr_20241209_182206_fold1.csv
#
#               precision    recall  f1-score   support
#
# Disease Free       1.00      1.00      1.00        88
#    Leaf Rust       0.97      0.98      0.97        98
#    Leaf Spot       0.94      0.91      0.92        33
#
#     accuracy                           0.98       219
#    macro avg       0.97      0.96      0.97       219
# weighted avg       0.98      0.98      0.98       219
#
#
# ================================================================================
# Fold #2
# ================================================================================
# Extracted fold2 from /kaggle/input/mblf-dataprep/data_msr/fold2.zip
# Found 7512 files belonging to 3 classes.
# Found 218 files belonging to 3 classes.
# Epoch 1/80
# 118/118 - 98s - 834ms/step - accuracy: 0.7804 - loss: 0.5584 - precision: 0.8048 - recall: 0.7548 - val_accuracy: 0.8578 - val_loss: 0.3420 - val_precision: 0.8857 - val_recall: 0.8532
# Epoch 2/80
# 118/118 - 12s - 102ms/step - accuracy: 0.9587 - loss: 0.1166 - precision: 0.9640 - recall: 0.9554 - val_accuracy: 0.8761 - val_loss: 0.3102 - val_precision: 0.8796 - val_recall: 0.8716
# Epoch 3/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9814 - loss: 0.0574 - precision: 0.9830 - recall: 0.9791 - val_accuracy: 0.8532 - val_loss: 0.3868 - val_precision: 0.8565 - val_recall: 0.8486
# Epoch 4/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9907 - loss: 0.0320 - precision: 0.9912 - recall: 0.9901 - val_accuracy: 0.8899 - val_loss: 0.3274 - val_precision: 0.8894 - val_recall: 0.8853
# Epoch 5/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9935 - loss: 0.0227 - precision: 0.9941 - recall: 0.9927 - val_accuracy: 0.9083 - val_loss: 0.2890 - val_precision: 0.9078 - val_recall: 0.9037
# Epoch 6/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9973 - loss: 0.0122 - precision: 0.9973 - recall: 0.9971 - val_accuracy: 0.8991 - val_loss: 0.3313 - val_precision: 0.9028 - val_recall: 0.8945
# Epoch 7/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9983 - loss: 0.0086 - precision: 0.9983 - recall: 0.9983 - val_accuracy: 0.9037 - val_loss: 0.3431 - val_precision: 0.9032 - val_recall: 0.8991
# Epoch 8/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9977 - loss: 0.0079 - precision: 0.9980 - recall: 0.9977 - val_accuracy: 0.8853 - val_loss: 0.4438 - val_precision: 0.8935 - val_recall: 0.8853
# Epoch 9/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9991 - loss: 0.0054 - precision: 0.9991 - recall: 0.9989 - val_accuracy: 0.8945 - val_loss: 0.3962 - val_precision: 0.8945 - val_recall: 0.8945
# Epoch 10/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9989 - loss: 0.0052 - precision: 0.9989 - recall: 0.9989 - val_accuracy: 0.9037 - val_loss: 0.3807 - val_precision: 0.9037 - val_recall: 0.9037
# Epoch 11/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9993 - loss: 0.0037 - precision: 0.9993 - recall: 0.9993 - val_accuracy: 0.9174 - val_loss: 0.3092 - val_precision: 0.9217 - val_recall: 0.9174
# Epoch 12/80
# 118/118 - 12s - 100ms/step - accuracy: 0.9997 - loss: 0.0029 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9220 - val_loss: 0.2991 - val_precision: 0.9220 - val_recall: 0.9220
# Epoch 13/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9997 - loss: 0.0027 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9220 - val_loss: 0.2624 - val_precision: 0.9220 - val_recall: 0.9220
# Epoch 14/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9993 - loss: 0.0026 - precision: 0.9993 - recall: 0.9993 - val_accuracy: 0.9358 - val_loss: 0.2071 - val_precision: 0.9358 - val_recall: 0.9358
# Epoch 15/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9997 - loss: 0.0021 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9495 - val_loss: 0.1952 - val_precision: 0.9495 - val_recall: 0.9495
# Epoch 16/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9997 - loss: 0.0022 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9495 - val_loss: 0.1814 - val_precision: 0.9495 - val_recall: 0.9495
# Epoch 17/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9997 - loss: 0.0017 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9587 - val_loss: 0.1357 - val_precision: 0.9587 - val_recall: 0.9587
# Epoch 18/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9996 - loss: 0.0018 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9587 - val_loss: 0.1529 - val_precision: 0.9587 - val_recall: 0.9587
# Epoch 19/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9993 - loss: 0.0021 - precision: 0.9993 - recall: 0.9993 - val_accuracy: 0.9587 - val_loss: 0.1313 - val_precision: 0.9587 - val_recall: 0.9587
# Epoch 20/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 6.6233e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9587 - val_loss: 0.1210 - val_precision: 0.9587 - val_recall: 0.9587
# Epoch 21/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9997 - loss: 0.0011 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9633 - val_loss: 0.0962 - val_precision: 0.9677 - val_recall: 0.9633
# Epoch 22/80
# 118/118 - 12s - 101ms/step - accuracy: 1.0000 - loss: 8.4478e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.0892 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 23/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9995 - loss: 0.0016 - precision: 0.9995 - recall: 0.9995 - val_accuracy: 0.9633 - val_loss: 0.0809 - val_precision: 0.9633 - val_recall: 0.9633
# Epoch 24/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9997 - loss: 9.3066e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9725 - val_loss: 0.0555 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 25/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9999 - loss: 5.0078e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9771 - val_loss: 0.0562 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 26/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9997 - loss: 9.7903e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9679 - val_loss: 0.0632 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 27/80
# 118/118 - 12s - 101ms/step - accuracy: 1.0000 - loss: 7.4402e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0434 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 28/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 7.2258e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0377 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 29/80
# 118/118 - 21s - 180ms/step - accuracy: 0.9999 - loss: 5.2451e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9862 - val_loss: 0.0252 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 30/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.2086e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.0254 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 31/80
# 118/118 - 20s - 172ms/step - accuracy: 1.0000 - loss: 3.1873e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0273 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 32/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.9055e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.0393 - val_precision: 0.9862 - val_recall: 0.9817
# Epoch 33/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.6503e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0403 - val_precision: 0.9816 - val_recall: 0.9771
# Epoch 34/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.5815e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0432 - val_precision: 0.9816 - val_recall: 0.9771
# Epoch 35/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9997 - loss: 6.7333e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9817 - val_loss: 0.0418 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 36/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 2.1783e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0465 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 37/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.5355e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0506 - val_precision: 0.9816 - val_recall: 0.9771
# Epoch 38/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 5.6627e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.0579 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 39/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.8328e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0589 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 40/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.8166e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0664 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 41/80
# 118/118 - 20s - 173ms/step - accuracy: 1.0000 - loss: 1.5456e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0559 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 42/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.9400e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0603 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 43/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 2.7533e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9771 - val_loss: 0.0547 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 44/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 4.3199e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.0820 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 45/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9997 - loss: 4.3554e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9725 - val_loss: 0.0726 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 46/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9995 - loss: 0.0023 - precision: 0.9995 - recall: 0.9995 - val_accuracy: 0.9725 - val_loss: 0.0774 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 47/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 5.1146e-04 - precision: 1.0000 - recall: 0.9999 - val_accuracy: 0.9817 - val_loss: 0.0759 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 48/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 4.3773e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9817 - val_loss: 0.0631 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 49/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.3717e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0687 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 50/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 2.2332e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0710 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 51/80
# 118/118 - 21s - 174ms/step - accuracy: 1.0000 - loss: 1.9119e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0696 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 52/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.1673e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0621 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 53/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 7.1584e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0585 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 54/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 2.1950e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0792 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 55/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.0788e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.0783 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 56/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.3254e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0712 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 57/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 7.4749e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0673 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 58/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 6.6917e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0495 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 59/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 4.1803e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0515 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 60/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 3.2980e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.0617 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 61/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.2226e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0488 - val_precision: 0.9816 - val_recall: 0.9771
# Epoch 62/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 3.5683e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0463 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 63/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.5502e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0432 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 64/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.8919e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0444 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 65/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.2752e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0838 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 66/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 3.7894e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0797 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 67/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.7973e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0742 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 68/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 4.8930e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0784 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 69/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.3105e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0590 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 70/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 3.3910e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0613 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 71/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 8.2292e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0574 - val_precision: 0.9816 - val_recall: 0.9771
# Epoch 72/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 5.0257e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.0597 - val_precision: 0.9724 - val_recall: 0.9679
# Epoch 73/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 4.3038e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9633 - val_loss: 0.0645 - val_precision: 0.9677 - val_recall: 0.9633
# Epoch 74/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 2.5490e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0569 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 75/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 4.0284e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0508 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 76/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.3551e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.0478 - val_precision: 0.9677 - val_recall: 0.9633
# Epoch 77/80
# 118/118 - 20s - 173ms/step - accuracy: 1.0000 - loss: 6.1235e-06 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9633 - val_loss: 0.0472 - val_precision: 0.9677 - val_recall: 0.9633
# Epoch 78/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.0916e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9587 - val_loss: 0.0446 - val_precision: 0.9631 - val_recall: 0.9587
# Epoch 79/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.1856e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0390 - val_precision: 0.9816 - val_recall: 0.9771
# Epoch 80/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.2398e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0379 - val_precision: 0.9817 - val_recall: 0.9817
#
# Model saved in: /kaggle/working/model_mblf_mobilenetv2_msr_20241209_182206_fold2.keras
# History saved in: /kaggle/working/history_mblf_mobilenetv2_msr_20241209_182206_fold2.csv
#
#               precision    recall  f1-score   support
#
# Disease Free       0.99      1.00      0.99        88
#    Leaf Rust       0.99      0.98      0.98        98
#    Leaf Spot       0.97      0.97      0.97        32
#
#     accuracy                           0.99       218
#    macro avg       0.98      0.98      0.98       218
# weighted avg       0.99      0.99      0.99       218
#
#
# ================================================================================
# Fold #3
# ================================================================================
# Extracted fold3 from /kaggle/input/mblf-dataprep/data_msr/fold3.zip
# Found 7512 files belonging to 3 classes.
# Found 218 files belonging to 3 classes.
# Epoch 1/80
# 118/118 - 88s - 747ms/step - accuracy: 0.7537 - loss: 0.6199 - precision: 0.7781 - recall: 0.7208 - val_accuracy: 0.6927 - val_loss: 0.7130 - val_precision: 0.7024 - val_recall: 0.6606
# Epoch 2/80
# 118/118 - 12s - 102ms/step - accuracy: 0.9525 - loss: 0.1322 - precision: 0.9576 - recall: 0.9479 - val_accuracy: 0.7936 - val_loss: 0.6036 - val_precision: 0.7944 - val_recall: 0.7798
# Epoch 3/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9802 - loss: 0.0626 - precision: 0.9817 - recall: 0.9784 - val_accuracy: 0.8394 - val_loss: 0.5027 - val_precision: 0.8411 - val_recall: 0.8257
# Epoch 4/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9884 - loss: 0.0381 - precision: 0.9889 - recall: 0.9874 - val_accuracy: 0.8853 - val_loss: 0.4067 - val_precision: 0.8925 - val_recall: 0.8761
# Epoch 5/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9937 - loss: 0.0241 - precision: 0.9944 - recall: 0.9935 - val_accuracy: 0.9037 - val_loss: 0.3400 - val_precision: 0.9028 - val_recall: 0.8945
# Epoch 6/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9956 - loss: 0.0155 - precision: 0.9961 - recall: 0.9955 - val_accuracy: 0.8899 - val_loss: 0.3769 - val_precision: 0.8940 - val_recall: 0.8899
# Epoch 7/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9983 - loss: 0.0097 - precision: 0.9984 - recall: 0.9983 - val_accuracy: 0.8991 - val_loss: 0.3418 - val_precision: 0.9032 - val_recall: 0.8991
# Epoch 8/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9985 - loss: 0.0072 - precision: 0.9985 - recall: 0.9985 - val_accuracy: 0.8991 - val_loss: 0.3046 - val_precision: 0.8991 - val_recall: 0.8991
# Epoch 9/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9987 - loss: 0.0060 - precision: 0.9987 - recall: 0.9987 - val_accuracy: 0.9174 - val_loss: 0.2538 - val_precision: 0.9174 - val_recall: 0.9174
# Epoch 10/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9991 - loss: 0.0050 - precision: 0.9992 - recall: 0.9991 - val_accuracy: 0.9358 - val_loss: 0.2028 - val_precision: 0.9358 - val_recall: 0.9358
# Epoch 11/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9992 - loss: 0.0042 - precision: 0.9992 - recall: 0.9992 - val_accuracy: 0.9450 - val_loss: 0.1767 - val_precision: 0.9493 - val_recall: 0.9450
# Epoch 12/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9996 - loss: 0.0034 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9495 - val_loss: 0.1503 - val_precision: 0.9493 - val_recall: 0.9450
# Epoch 13/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 0.0019 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9495 - val_loss: 0.1312 - val_precision: 0.9493 - val_recall: 0.9450
# Epoch 14/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9996 - loss: 0.0035 - precision: 0.9996 - recall: 0.9993 - val_accuracy: 0.9495 - val_loss: 0.1280 - val_precision: 0.9539 - val_recall: 0.9495
# Epoch 15/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9997 - loss: 0.0024 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9541 - val_loss: 0.1293 - val_precision: 0.9539 - val_recall: 0.9495
# Epoch 16/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9991 - loss: 0.0031 - precision: 0.9991 - recall: 0.9991 - val_accuracy: 0.9587 - val_loss: 0.1028 - val_precision: 0.9631 - val_recall: 0.9587
# Epoch 17/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9996 - loss: 0.0025 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9771 - val_loss: 0.0931 - val_precision: 0.9770 - val_recall: 0.9725
# Epoch 18/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9996 - loss: 0.0017 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9725 - val_loss: 0.0829 - val_precision: 0.9769 - val_recall: 0.9679
# Epoch 19/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 0.0013 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0805 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 20/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9995 - loss: 0.0016 - precision: 0.9995 - recall: 0.9995 - val_accuracy: 0.9771 - val_loss: 0.0663 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 21/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9999 - loss: 0.0010 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9817 - val_loss: 0.0570 - val_precision: 0.9816 - val_recall: 0.9771
# Epoch 22/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9997 - loss: 0.0013 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9817 - val_loss: 0.0604 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 23/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9996 - loss: 0.0013 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9862 - val_loss: 0.0577 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 24/80
# 118/118 - 12s - 102ms/step - accuracy: 1.0000 - loss: 7.9821e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0465 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 25/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 7.0895e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0435 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 26/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9995 - loss: 0.0013 - precision: 0.9995 - recall: 0.9995 - val_accuracy: 0.9862 - val_loss: 0.0461 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 27/80
# 118/118 - 20s - 174ms/step - accuracy: 0.9999 - loss: 5.8427e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9908 - val_loss: 0.0540 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 28/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 4.9923e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0510 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 29/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.8789e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0527 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 30/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 5.8903e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9908 - val_loss: 0.0504 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 31/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 4.4356e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.0533 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 32/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.5938e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0595 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 33/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.3115e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0518 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 34/80
# 118/118 - 21s - 175ms/step - accuracy: 1.0000 - loss: 3.0989e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0499 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 35/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 4.5219e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9908 - val_loss: 0.0545 - val_precision: 0.9908 - val_recall: 0.9862
# Epoch 36/80
# 118/118 - 20s - 174ms/step - accuracy: 1.0000 - loss: 2.0965e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0516 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 37/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.7397e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0507 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 38/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.9146e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0478 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 39/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.6312e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0447 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 40/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 2.4133e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0417 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 41/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 3.2182e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9908 - val_loss: 0.0449 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 42/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.5687e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0563 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 43/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.4737e-04 - precision: 1.0000 - recall: 0.9999 - val_accuracy: 0.9908 - val_loss: 0.0596 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 44/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.4326e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0844 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 45/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 1.3468e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0769 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 46/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9995 - loss: 0.0016 - precision: 0.9995 - recall: 0.9995 - val_accuracy: 0.9908 - val_loss: 0.0733 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 47/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 3.2596e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9862 - val_loss: 0.0705 - val_precision: 0.9862 - val_recall: 0.9862
# Epoch 48/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9997 - loss: 0.0012 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9908 - val_loss: 0.0504 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 49/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9996 - loss: 9.7262e-04 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9908 - val_loss: 0.0355 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 50/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9996 - loss: 6.3420e-04 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9908 - val_loss: 0.0587 - val_precision: 0.9908 - val_recall: 0.9908
# Epoch 51/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9997 - loss: 6.6574e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9817 - val_loss: 0.0929 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 52/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9997 - loss: 7.6026e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9817 - val_loss: 0.0994 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 53/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9999 - loss: 4.5850e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9817 - val_loss: 0.0773 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 54/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.3554e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0703 - val_precision: 0.9862 - val_recall: 0.9817
# Epoch 55/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 3.9042e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9862 - val_loss: 0.0866 - val_precision: 0.9862 - val_recall: 0.9817
# Epoch 56/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.7846e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.0620 - val_precision: 0.9862 - val_recall: 0.9817
# Epoch 57/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 7.3156e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9817 - val_loss: 0.0592 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 58/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 4.3598e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9817 - val_loss: 0.0556 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 59/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.5216e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0523 - val_precision: 0.9862 - val_recall: 0.9817
# Epoch 60/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 2.2001e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0704 - val_precision: 0.9862 - val_recall: 0.9817
# Epoch 61/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 6.9630e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0699 - val_precision: 0.9862 - val_recall: 0.9817
# Epoch 62/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 6.5253e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.0767 - val_precision: 0.9862 - val_recall: 0.9817
# Epoch 63/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 4.2518e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9862 - val_loss: 0.0789 - val_precision: 0.9862 - val_recall: 0.9817
# Epoch 64/80
# 118/118 - 11s - 94ms/step - accuracy: 0.9999 - loss: 3.7333e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9817 - val_loss: 0.0656 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 65/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.0409e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0811 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 66/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 9.9484e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0814 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 67/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 8.9837e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0814 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 68/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 4.8429e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0805 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 69/80
# ...
# Epoch 4/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9940 - loss: 0.0264 - precision: 0.9945 - recall: 0.9935 - val_accuracy: 0.9266 - val_loss: 0.1606 - val_precision: 0.9263 - val_recall: 0.9220
# Epoch 5/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9957 - loss: 0.0177 - precision: 0.9960 - recall: 0.9955 - val_accuracy: 0.9312 - val_loss: 0.1725 - val_precision: 0.9355 - val_recall: 0.9312
# Epoch 6/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9975 - loss: 0.0121 - precision: 0.9976 - recall: 0.9975 - val_accuracy: 0.9312 - val_loss: 0.1546 - val_precision: 0.9312 - val_recall: 0.9312
# Epoch 7/80
# 118/118 - 12s - 101ms/step - accuracy: 0.9969 - loss: 0.0105 - precision: 0.9971 - recall: 0.9967 - val_accuracy: 0.9404 - val_loss: 0.1472 - val_precision: 0.9401 - val_recall: 0.9358
# Epoch 8/80
# 118/118 - 12s - 102ms/step - accuracy: 0.9997 - loss: 0.0053 - precision: 0.9997 - recall: 0.9996 - val_accuracy: 0.9450 - val_loss: 0.1409 - val_precision: 0.9450 - val_recall: 0.9450
# Epoch 9/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9989 - loss: 0.0058 - precision: 0.9989 - recall: 0.9989 - val_accuracy: 0.9404 - val_loss: 0.1559 - val_precision: 0.9447 - val_recall: 0.9404
# Epoch 10/80
# 118/118 - 12s - 102ms/step - accuracy: 0.9996 - loss: 0.0039 - precision: 0.9996 - recall: 0.9995 - val_accuracy: 0.9495 - val_loss: 0.1658 - val_precision: 0.9539 - val_recall: 0.9495
# Epoch 11/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9996 - loss: 0.0033 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9450 - val_loss: 0.1411 - val_precision: 0.9447 - val_recall: 0.9404
# Epoch 12/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9993 - loss: 0.0032 - precision: 0.9993 - recall: 0.9993 - val_accuracy: 0.9495 - val_loss: 0.1295 - val_precision: 0.9495 - val_recall: 0.9495
# Epoch 13/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9995 - loss: 0.0031 - precision: 0.9995 - recall: 0.9995 - val_accuracy: 0.9495 - val_loss: 0.1306 - val_precision: 0.9495 - val_recall: 0.9495
# Epoch 14/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9997 - loss: 0.0015 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9450 - val_loss: 0.1436 - val_precision: 0.9450 - val_recall: 0.9450
# Epoch 15/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9996 - loss: 0.0021 - precision: 0.9996 - recall: 0.9996 - val_accuracy: 0.9495 - val_loss: 0.1257 - val_precision: 0.9495 - val_recall: 0.9495
# Epoch 16/80
# 118/118 - 12s - 102ms/step - accuracy: 0.9997 - loss: 0.0015 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9633 - val_loss: 0.1088 - val_precision: 0.9722 - val_recall: 0.9633
# Epoch 17/80
# 118/118 - 12s - 102ms/step - accuracy: 0.9997 - loss: 0.0015 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9679 - val_loss: 0.1133 - val_precision: 0.9676 - val_recall: 0.9587
# Epoch 18/80
# 118/118 - 12s - 101ms/step - accuracy: 1.0000 - loss: 0.0011 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0960 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 19/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 7.6430e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0970 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 20/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 5.9517e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0943 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 21/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 5.6932e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.0922 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 22/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9997 - loss: 0.0010 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9725 - val_loss: 0.0900 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 23/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 8.0660e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9725 - val_loss: 0.0940 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 24/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 6.4071e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0998 - val_precision: 0.9769 - val_recall: 0.9679
# Epoch 25/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 9.0255e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9679 - val_loss: 0.0926 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 26/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 8.3452e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0873 - val_precision: 0.9724 - val_recall: 0.9679
# Epoch 27/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 3.8489e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0860 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 28/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 4.7607e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9679 - val_loss: 0.0886 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 29/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.5103e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0860 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 30/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.9379e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9679 - val_loss: 0.0831 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 31/80
# 118/118 - 12s - 101ms/step - accuracy: 1.0000 - loss: 2.4243e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0776 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 32/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 3.1675e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0787 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 33/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.6878e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0824 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 34/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.2434e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0835 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 35/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.1263e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0813 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 36/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.8496e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.0841 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 37/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.7902e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0923 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 38/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.7698e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0913 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 39/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9997 - loss: 5.7304e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9771 - val_loss: 0.1181 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 40/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.4661e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1084 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 41/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.0948e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.0991 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 42/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.2505e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1047 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 43/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.8406e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1056 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 44/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.1416e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1079 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 45/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 9.6096e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1022 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 46/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.5864e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1214 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 47/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 4.6526e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1199 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 48/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 6.8561e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1126 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 49/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.5205e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1088 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 50/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 3.7062e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9633 - val_loss: 0.1141 - val_precision: 0.9677 - val_recall: 0.9633
# Epoch 51/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.4609e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1273 - val_precision: 0.9770 - val_recall: 0.9725
# Epoch 52/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 1.4643e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1147 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 53/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 3.1221e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9771 - val_loss: 0.1049 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 54/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 6.5690e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1200 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 55/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.1998e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1117 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 56/80
# 118/118 - 21s - 174ms/step - accuracy: 1.0000 - loss: 7.3010e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1050 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 57/80
# 118/118 - 12s - 101ms/step - accuracy: 1.0000 - loss: 5.7747e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0961 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 58/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 4.6351e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0969 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 59/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9997 - loss: 4.3391e-04 - precision: 0.9999 - recall: 0.9997 - val_accuracy: 0.9679 - val_loss: 0.1127 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 60/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 6.4666e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1210 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 61/80
# 118/118 - 11s - 96ms/step - accuracy: 0.9999 - loss: 2.6859e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9771 - val_loss: 0.1224 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 62/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.0917e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1359 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 63/80
# 118/118 - 11s - 94ms/step - accuracy: 1.0000 - loss: 5.6618e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1297 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 64/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9999 - loss: 2.9158e-04 - precision: 0.9999 - recall: 0.9999 - val_accuracy: 0.9771 - val_loss: 0.1152 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 65/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9997 - loss: 7.1638e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9771 - val_loss: 0.0988 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 66/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 2.6060e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1115 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 67/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.3775e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1048 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 68/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 9.9371e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1257 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 69/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 4.7983e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1332 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 70/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 2.2838e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1225 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 71/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.7256e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9725 - val_loss: 0.1450 - val_precision: 0.9725 - val_recall: 0.9725
# Epoch 72/80
# 118/118 - 11s - 95ms/step - accuracy: 0.9997 - loss: 8.9043e-04 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.9817 - val_loss: 0.2357 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 73/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 9.6096e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.2018 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 74/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 3.8663e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1638 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 75/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 3.6220e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1635 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 76/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 3.5853e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1519 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 77/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 1.9588e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9771 - val_loss: 0.1406 - val_precision: 0.9771 - val_recall: 0.9771
# Epoch 78/80
# 118/118 - 11s - 95ms/step - accuracy: 1.0000 - loss: 9.9854e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0562 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 79/80
# 118/118 - 20s - 172ms/step - accuracy: 1.0000 - loss: 2.0047e-05 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0580 - val_precision: 0.9817 - val_recall: 0.9817
# Epoch 80/80
# 118/118 - 11s - 96ms/step - accuracy: 1.0000 - loss: 7.2452e-06 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9817 - val_loss: 0.0582 - val_precision: 0.9817 - val_recall: 0.9817
#
# Model saved in: /kaggle/working/model_mblf_mobilenetv2_msr_20241209_182206_fold5.keras
# History saved in: /kaggle/working/history_mblf_mobilenetv2_msr_20241209_182206_fold5.csv
#
#               precision    recall  f1-score   support
#
# Disease Free       0.99      1.00      0.99        88
#    Leaf Rust       0.99      0.97      0.98        97
#    Leaf Spot       0.94      0.97      0.96        33
#
#     accuracy                           0.98       218
#    macro avg       0.97      0.98      0.98       218
# weighted avg       0.98      0.98      0.98       218

# %% [markdown]
# # 4. Display Results

# %%
for idx in range(N_FOLDS):
    _fold_str = f'Fold #{idx+1}'

    # Print individual test results
    print(f'\nResults for {_fold_str}:')
    print('----------------------------------------')
    print(f'Loss       : {score_lst[idx][0]:.6f}')
    print(f'Accuracy   : {score_lst[idx][1]:.6f}')
    print(f'Precision  : {score_lst[idx][2]:.6f}')
    print(f'Recall     : {score_lst[idx][3]:.6f}')
    print(f'F1 Score   : {f1_lst[idx]:.6f}')

    # Plot individual training curves
    plt.figure(figsize=(20, 5))
    
    plt.subplot(1,2,1)
    plt.plot(df_lst[idx].loss, label='Training Loss')
    plt.plot(df_lst[idx].val_loss, label='Validation Loss')
    plt.title("Loss for "+_fold_str)
    plt.grid()
    plt.legend()
    plt.subplot(1,2,2)
    plt.plot(df_lst[idx].accuracy, label='Training Accuracy')
    plt.plot(df_lst[idx].val_accuracy, label='Validation Accuracy')
    plt.title("Accuracy for "+_fold_str)
    plt.grid()
    plt.legend()
    plt.show()
    
    # Plot individual confusion matrix
    cmd = ConfusionMatrixDisplay(cm_lst[idx], display_labels=DISPLAY_LABELS)
    cmd.plot(cmap='Blues')
    plt.show()
    
    # Plot ROC and AUC for each class
    cls_auc_lst = plot_roc_auc(all_y_true[idx], all_y_pred[idx], num_classes=3, display_labels=DISPLAY_LABELS, title=f'ROC Curve for Fold #{idx+1}')
    for i, cls_auc in enumerate(cls_auc_lst):
        print(f'AUC for {DISPLAY_LABELS[i]:<15}: {cls_auc:.6f}')
    
    print('')
    pass
# Out:
# Results for Fold #1:
# ----------------------------------------
# Loss       : 0.194343
# Accuracy   : 0.977169
# Precision  : 0.977169
# Recall     : 0.977169
# F1 Score   : 0.977169
# AUC for Disease Free   : 1.000000
# AUC for Leaf Rust      : 0.989669
# AUC for Leaf Spot      : 0.970349
#
#
# Results for Fold #2:
# ----------------------------------------
# Loss       : 0.025205
# Accuracy   : 0.986239
# Precision  : 0.986239
# Recall     : 0.986239
# F1 Score   : 0.986239
# AUC for Disease Free   : 0.999913
# AUC for Leaf Rust      : 0.999575
# AUC for Leaf Spot      : 0.999664
#
#
# Results for Fold #3:
# ----------------------------------------
# Loss       : 0.023108
# Accuracy   : 0.995413
# Precision  : 0.995392
# Recall     : 0.990826
# F1 Score   : 0.995413
# AUC for Disease Free   : 1.000000
# AUC for Leaf Rust      : 0.999830
# AUC for Leaf Spot      : 0.999832
#
#
# Results for Fold #4:
# ----------------------------------------
# Loss       : 0.111018
# Accuracy   : 0.986239
# Precision  : 0.986239
# Recall     : 0.986239
# F1 Score   : 0.986239
# AUC for Disease Free   : 1.000000
# AUC for Leaf Rust      : 0.998002
# AUC for Leaf Spot      : 0.992944
#
#
# Results for Fold #5:
# ----------------------------------------
# Loss       : 0.096100
# Accuracy   : 0.981651
# Precision  : 0.981651
# Recall     : 0.981651
# F1 Score   : 0.981651
# AUC for Disease Free   : 1.000000
# AUC for Leaf Rust      : 0.998211
# AUC for Leaf Spot      : 0.997379

# %%
# Aggregate results
avg_score = np.mean(score_lst, axis=0)
avg_f1 = np.mean(f1_lst, axis=0)
avg_df = reduce(lambda a, b: a.add(b, fill_value=0), df_lst) / 5.0
avg_cm = np.mean(cm_lst, axis=0)
all_y_true = np.concatenate(all_y_true, axis=0)
all_y_pred = np.concatenate(all_y_pred, axis=0)

# Print aggregated test results
print('Cross-Validation Results:')
print('----------------------------------------')
print(f'Average Loss       : {avg_score[0]:.6f}')
print(f'Average Accuracy   : {avg_score[1]:.6f}')
print(f'Average Precision  : {avg_score[2]:.6f}')
print(f'Average Recall     : {avg_score[3]:.6f}')
print(f'Average F1 Score   : {avg_f1:.6f}')

# Plot aggregated training curves
plt.figure(figsize=(10, 5))
plt.plot(avg_df.loss, label='Training Loss')
plt.plot(avg_df.val_loss, label='Validation Loss')
plt.title("Aggregated Loss")
plt.grid()
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(avg_df.accuracy, label='Training Accuracy')
plt.plot(avg_df.val_accuracy, label='Validation Accuracy')
plt.title("Aggregated Accuracy")
plt.grid()
plt.legend()
plt.show()

# Plot aggregated confusion matrix
cmd = ConfusionMatrixDisplay(avg_cm, display_labels=DISPLAY_LABELS)
cmd.plot(cmap='Blues')
plt.show()
# Out:
# Cross-Validation Results:
# ----------------------------------------
# Average Loss       : 0.089955
# Average Accuracy   : 0.985342
# Average Precision  : 0.985338
# Average Recall     : 0.984425
# Average F1 Score   : 0.985342

# %%
# Plot aggregated ROC, AUC
cls_auc_lst = plot_roc_auc(all_y_true, all_y_pred, num_classes=3, display_labels=DISPLAY_LABELS, title=f'ROC Curve')
for i, cls_auc in enumerate(cls_auc_lst):
    print(f'AUC for {DISPLAY_LABELS[i]:<15}: {cls_auc:.6f}')
# Out:
# AUC for Disease Free   : 0.999965
# AUC for Leaf Rust      : 0.997354
# AUC for Leaf Spot      : 0.993129
